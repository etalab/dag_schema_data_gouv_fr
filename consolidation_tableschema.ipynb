# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import requests
import json
from json import JSONDecodeError
import chardet
import csv
from io import StringIO
import datetime
from pathlib import Path
import os
import yaml
from datetime import datetime
import time
import emails
import shutil

# %% [markdown]
# # Parameters

# %%
#API PARAMETERS

api_url = API_URL

HEADERS = {
    'X-API-KEY': API_KEY,
    }

# %%
#MAIL PARAMETERS
# smtp_host = os.environ['SCHEMA_BOT_MAIL_SMTP']
# smtp_user = os.environ['SCHEMA_BOT_MAIL_USER']
# smtp_password = os.environ['SCHEMA_BOT_MAIL_PASSWORD']

# %%
current_path = Path(WORKING_DIR)
current_path
# Out:
# PosixPath('/Users/geoffrey/projects/consolidation-schemas')

# %%
tmp_path = Path(TMP_FOLDER)

# %%
config_path = os.path.join(current_path, 'config_tableschema.yml')

# %%
schemas_list_url = 'https://schema.data.gouv.fr/schemas/schemas.json'

# %%
schema_url_base = api_url + 'datasets/?schema={schema_name}'
tag_url_base = api_url + 'datasets/?tag={tag}'
search_url_base = api_url + 'datasets?q={search_word}'

# %%
validata_base_url = "https://validata-api.app.etalab.studio/validate?schema={schema_url}&url={rurl}"

# %%
#Template for consolidation datasets title

datasets_title_template = 'Fichiers consolidés des données respectant le schéma "{schema_title}"'

#Template for consolidation datasets description (Markdown)

datasets_description_template = '''
Ceci est un jeu de données généré automatiquement par Etalab. Il regroupe les données qui respectent le schéma {schema_name}, par version du schéma.

La fiche présentant le schéma et ses caractéristiques est disponible sur [https://schema.data.gouv.fr/{schema_name}/latest.html](https://schema.data.gouv.fr/{schema_name}/latest.html)

### Qu'est-ce qu'un schéma ?

Les schémas de données permettent de décrire des modèles de données : quels sont les différents champs, comment sont représentées les données, quelles sont les valeurs possibles, etc.

Vous pouvez retrouver l'ensemble des schémas au référentiel sur le site schema.data.gouv.fr

### Comment sont produites ces données ?

Ces données sont produites à partir des ressources publiées sur le site [data.gouv.fr](http://data.gouv.fr) par différents producteurs. Etalab détecte automatiquement les ressources qui obéissent à un schéma et concatène l'ensemble des données en un seul fichier, par version de schéma.

Ces fichiers consolidés permettent aux réutilisateurs de manipuler un seul fichier plutôt qu'une multitude de ressources et contribue ainsi à améliorer la qualité de l'open data.

### Comment intégrer mes données dans ces fichiers consolidés ?

Si vous êtes producteurs de données et que vous ne retrouvez pas vos données dans ces fichiers consolidés, c'est probablement parce que votre ressource sur [data.gouv.fr](http://data.gouv.fr) n'est pas conforme au schéma. Vous pouvez vérifier la conformité de votre ressource via l'outil [https://publier.etalab.studio/upload?schema={schema_name}](https://publier.etalab.studio/upload?schema={schema_name})

En cas de problème persistant, vous pouvez contacter le support data.gouv [lien vers [https://support.data.gouv.fr/](https://support.data.gouv.fr/)].

### Comment produire des données conformes ?

Un certain nombre d'outils existent pour accompagner les producteurs de données. Vous pouvez notamment vous connecter sur le site [https://publier.etalab.studio/select?schema={schema_name}](https://publier.etalab.studio/select?schema={schema_name}) pour pouvoir saisir vos données selon trois modes :

- upload de fichier existant
- saisie via formulaire
- saisie via tableur
'''

# %%
#Template for mail/comment (added, updated and deleted schema)

added_schema_comment_template = '''
Bonjour,

Vous recevez ce message car suite à un contrôle automatique de vos données par notre robot de validation, nous constatons que le fichier {resource_title} de ce jeu de données est conforme au schéma {schema_name} (version {most_recent_valid_version}).
Nous avons donc automatiquement ajouté à ce fichier la métadonnée de schéma correspondante, ce qui atteste de la qualité des données que vous avez publiées.

Une question ? Écrivez à validation@data.gouv.fr en incluant l'URL du jeu de données concerné.
'''

updated_schema_comment_template = '''
Bonjour,

Vous recevez ce message car suite à un contrôle automatique de vos données par notre robot de validation, nous constatons que le fichier {resource_title} de ce jeu de données (qui respecte le schéma {schema_name}) n'avait pas dans ses métadonnées la version de schéma la plus récente qu'il respecte.
Nous avons donc automatiquement mis à jour les métadonnées du fichier en indiquant la version adéquate du schéma.

Version précédemment indiquée : {initial_version_name}
Version mise à jour : {most_recent_valid_version}

Une question ? Écrivez à validation@data.gouv.fr en incluant l'URL du jeu de données concerné.
'''

deleted_schema_mail_template_org = '''
Bonjour,<br />
<br />
Vous recevez ce message automatique car vous êtes admin de l'organisation {organisation_name} sur data.gouv.fr. Votre organisation a publié le jeu de données {dataset_title}, dont le fichier {resource_title} se veut conforme au schéma {schema_name}.<br />
Cependant, suite à un contrôle automatique de vos données par notre robot de validation, il s'avère que ce fichier ne respecte aucune version de ce schéma.<br />
Nous avons donc automatiquement supprimé la métadonnée de schéma associée à ce fichier.<br />
<br />
Vous pouvez consulter le [rapport de validation](https://validata.etalab.studio/table-schema?input=url&schema_url={schema_url}&url={resource_url}&repair=true) pour vous aider à corriger les erreurs (ce rapport est relatif à la version la plus récente du schéma, mais votre fichier a bien été testé vis-à-vis de toutes les versions possibles du schéma).<br />
<br />
Vous pourrez alors restaurer la métadonnée de schéma une fois un fichier valide publié.<br />
<br />
Une question ? Écrivez à validation@data.gouv.fr en incluant l'URL du jeu de données concerné.<br />
<br />
Cordialement,<br />
<br />
L'équipe de data.gouv.fr
'''

deleted_schema_mail_template_own = '''
Bonjour,<br />
<br />
Vous recevez ce message automatique car vous avez publié sur data.gouv.fr le jeu de données {dataset_title}, dont le fichier {resource_title} se veut conforme au schéma {schema_name}.<br />
Cependant, suite à un contrôle automatique de vos données par notre robot de validation, il s'avère que ce fichier ne respecte aucune version de ce schéma.<br />
Nous avons donc automatiquement supprimé la métadonnée de schéma associée à ce fichier.<br />
<br />
Vous pouvez consulter le [rapport de validation](https://validata.etalab.studio/table-schema?input=url&schema_url={schema_url}&url={resource_url}&repair=true) pour vous aider à corriger les erreurs (ce rapport est relatif à la version la plus récente du schéma, mais votre fichier a bien été testé vis-à-vis de toutes les versions possibles du schéma).<br />
<br />
Vous pourrez alors restaurer la métadonnée de schéma une fois un fichier valide publié.<br />
<br />
Une question ? Écrivez à validation@data.gouv.fr en incluant l'URL du jeu de données concerné.<br />
<br />
Cordialement,<br />
<br />
L'équipe de data.gouv.fr
'''

deleted_schema_comment_template = '''
Bonjour,

Vous recevez ce message car suite à un contrôle automatique de vos données par notre robot de validation, nous constatons que le fichier {resource_title} de ce jeu de données se veut conforme au schéma {schema_name} alors qu'il ne respecte aucune version de ce schéma.
Nous avons donc automatiquement supprimé la métadonnée de schéma associée à ce fichier.

Vous pouvez consulter le [rapport de validation](https://validata.etalab.studio/table-schema?input=url&schema_url={schema_url}&url={resource_url}&repair=true) pour vous aider à corriger les erreurs (ce rapport est relatif à la version la plus récente du schéma, mais votre fichier a bien été testé vis-à-vis de toutes les versions possibles du schéma).

Vous pourrez alors restaurer la métadonnée de schéma une fois un fichier valide publié.

Une question ? Écrivez à validation@data.gouv.fr en incluant l'URL du jeu de données concerné.
'''

# %% [markdown]
# # Functions

# %%
#Get the dictionnary with information on the schema (when schemas catagalogue list already loaded)
def get_schema_dict(schema_name, schemas_catalogue_list) :
    res = None
    for schema in schemas_catalogue_list :
        if schema['name'] == schema_name :
            res = schema
    
    if res is None :
        print("No schema named '{}' found.".format(schema_name))
    
    return res

# %%
#Add the schema default configuration in the configuration YAML file
def add_schema_default_config(schema_name, config_path) :
    
    schema_dict = get_schema_dict(schema_name, schemas_catalogue_list)
    schema_title = schema_dict['title']
    
    default_schema_config_dict = {
        'consolidate': False,
        'search_words':[schema_title] # setting schema title as a default search keyword for resources
    }
    
    if os.path.exists(config_path) :
        with open(config_path, 'r') as infile :
            config_dict = yaml.safe_load(infile)
    else :
        config_dict = {}
        
    config_dict[schema_name] = default_schema_config_dict
    
    with open(config_path, 'w') as outfile:
        yaml.dump(config_dict, outfile, default_flow_style=False)

# %%
#API parsing to get resources infos based on schema metadata, tags and search keywords
def parse_api(url):
    r = requests.get(url)
    data = r.json()
    nb_pages = int(data['total']/data['page_size'])+1
    arr = []
    for i in range(1,nb_pages+1):
        r = requests.get(url+"&page="+str(i))
        data = r.json()
        for dataset in data['data']:
            for res in dataset['resources']:
                if 'format=csv' in res['url']:
                    filename = res['url'].split('/')[-3] + '.csv'
                else:
                    filename = res['url'].split('/')[-1]
                ext = filename.split('.')[-1]
                obj = {}
                obj['dataset_id'] = dataset['id']
                obj['dataset_title'] = dataset['title']
                obj['dataset_slug'] = dataset['slug']
                obj['dataset_page'] = dataset['page']
                obj['resource_id'] = res['id']
                obj['resource_title'] = res['title']
                obj['resource_url'] = res['url']
                obj['resource_last_modified'] = res['last_modified']
                if ext != 'csv':
                    obj['error_type'] = "wrong-file-format"
                else:
                    if not dataset['organization'] and not dataset['owner']:
                        obj['error_type'] = "orphan-dataset"
                    else:
                        obj['organization_or_owner'] = dataset['organization']['slug'] if dataset['organization'] else dataset['owner']['slug']
                        obj['error_type'] = None
                arr.append(obj)
    df = pd.DataFrame(arr)
    return df

# %%
#Make the validation report based on the resource url, schema url and validation url
def make_validata_report(rurl, schema_url, validata_base_url=validata_base_url) :
    r = requests.get(validata_base_url.format(schema_url=schema_url, rurl=rurl))
    time.sleep(0.5)
    return r.json()

# %%
#Returns if a resource is valid or not regarding a schema (version)
def is_validata_valid(rurl, schema_url, validata_base_url=validata_base_url) :
    try :
        report = make_validata_report(rurl, schema_url, validata_base_url=validata_base_url)
        try :
            res = report['report']['valid']
        except KeyError :
            print('{} ---- 🔴 No info in validata report for resource: {}'.format(datetime.today(), rurl))
            res = False
    except JSONDecodeError :
        print('{} ---- 🔴 Could not make JSON from validata report for resource: {}'.format(datetime.today(), rurl))
        res = False
    return res

# %%
#Returns if a resource is valid based on its "ref_table" row
def is_validata_valid_row(row, schema_url) :
    if row['error_type'] is None : #if no error
        rurl = row['resource_url']
        return is_validata_valid(rurl, schema_url)
    else :
        return False

# %%
#Creates a dataset on data.gouv.fr for consolidation files (used only if does not exist yet in config file)
def create_schema_consolidation_dataset(schema_name, schemas_catalogue_list, api_url) :
    global HEADERS, datasets_description_template, datasets_title_template
    
    schema_title = get_schema_dict(schema_name, schemas_catalogue_list)['title']
    
    response = requests.post(api_url + 'datasets/', json={
    'title': datasets_title_template.format(schema_title=schema_title),
    'description': datasets_description_template.format(schema_name=schema_name),
    'organization':'534fff75a3a7292c64a77de4',
    'license':'lov2'
    }, headers=HEADERS)
    
    return response

# %%
#Generic function to update a field (key) in the config file
def update_config_file(schema_name, key, value, config_path) :
    with open(config_path, 'r') as f :
        config_dict = yaml.safe_load(f)
    
    config_dict[schema_name][key] = value
    
    with open(config_path, 'w') as outfile:
        yaml.dump(config_dict, outfile, default_flow_style=False)

# %%
#Adds the resource ID of the consolidated file for a given schema version in the config file
def update_config_version_resource_id(schema_name, version_name, r_id, config_path) :
    with open(config_path, 'r') as f :
        config_dict = yaml.safe_load(f)
    
    if 'latest_resource_ids' not in config_dict[schema_name] :
        config_dict[schema_name]['latest_resource_ids'] = {version_name: r_id}
    else :
        config_dict[schema_name]['latest_resource_ids'][version_name] = r_id
        
    with open(config_path, 'w') as outfile:
        yaml.dump(config_dict, outfile, default_flow_style=False)

# %%
#Based on validation columns by version, adds a column to the ref_table that shows the most recent version of the schema for which the resource is valid
def add_most_recent_valid_version(df_ref) :
    
    version_cols_list = [col for col in df_ref.columns if col.startswith('is_valid_v_')]
    
    df_ref['most_recent_valid_version'] = ''
    
    for col in sorted(version_cols_list, reverse=True) :
        df_ref.loc[(df_ref['most_recent_valid_version'] == ''), 'most_recent_valid_version'] = df_ref.loc[(df_ref['most_recent_valid_version'] == ''), col].apply(lambda x : x*col.replace('is_valid_v_',''))
    
    df_ref.loc[(df_ref['most_recent_valid_version'] == ''), 'most_recent_valid_version'] = np.nan
    
    return df_ref

# %%
#Gets the current metadata of schema version of a resource (based of ref_table row)
def get_resource_schema_version(row, api_url) :
    
    dataset_id = row['dataset_id']
    resource_id = row['resource_id']
    
    url = api_url + 'datasets/{}/resources/{}/'.format(dataset_id, resource_id)
    r = requests.get(url)
    if r.status_code == 200 :
        r_json = r.json()
        if 'schema' in r_json.keys() :
            if 'version' in r_json['schema'].keys() :
                return r_json['schema']['version']
            else :
                return np.nan
        else :
            return np.nan
    else :
        return np.nan

#Returns if resource schema (version) metadata should be updated or not based on what we know about the resource
def is_schema_version_to_update(row) :
    initial_version_name = row['initial_version_name']
    most_recent_valid_version = row['most_recent_valid_version']
    resource_found_by = row['resource_found_by']
    
    return (resource_found_by == '1 - schema request') and (most_recent_valid_version == most_recent_valid_version) and (initial_version_name != most_recent_valid_version)

#Returns if resource schema (version) metadata should be added or not based on what we know about the resource
def is_schema_to_add(row) :
    resource_found_by = row['resource_found_by']
    is_valid_one_version = row['is_valid_one_version']
    
    return (resource_found_by != '1 - schema request') and is_valid_one_version

#Returns if resource schema (version) metadata should be deleted or not based on what we know about the resource
def is_schema_to_drop(row) :
    resource_found_by = row['resource_found_by']
    is_valid_one_version = row['is_valid_one_version']
    
    return (resource_found_by == '1 - schema request') and (is_valid_one_version == False)

# %%
#Function that adds a schema (version) metadata on a resource
def add_resource_schema(api_url, dataset_id, resource_id, schema_name, version_name) :
    
    global HEADERS
    
    schema = {
        "name": schema_name,
        "version": version_name
    }
    
    try :
        url = api_url + 'datasets/{}/resources/{}/'.format(dataset_id, resource_id)
        r = requests.get(url, headers=HEADERS)
        extras = r.json()['extras']
    except :
        extras = {}
    
    extras['consolidation_schema:add_schema'] = schema_name
    
    obj = {'schema': schema, 'extras': extras}
                
    url = api_url + 'datasets/{}/resources/{}/'.format(dataset_id, resource_id)
    response = requests.put(url, json=obj, headers=HEADERS)
    
    if response.status_code != 200 :
        print('🔴 Schema could not be added on resource. Dataset ID: {} - Resource ID: {}'.format(dataset_id, resource_id))
        
    return response.status_code == 200

# %%
#Function that updates a schema (version) metadata on a resource
def update_resource_schema(api_url, dataset_id, resource_id, schema_name, version_name) :
    
    global HEADERS
    
    schema = {
        "name": schema_name,
        "version": version_name
    }
    
    try :
        url = api_url + 'datasets/{}/resources/{}/'.format(dataset_id, resource_id)
        r = requests.get(url, headers=HEADERS)
        extras = r.json()['extras']
    except :
        extras = {}
    
    extras['consolidation_schema:update_schema'] = schema_name
    
    obj = {'schema': schema, 'extras': extras}
                
    url = api_url + 'datasets/{}/resources/{}/'.format(dataset_id, resource_id)
    response = requests.put(url, json=obj, headers=HEADERS)
    
    if response.status_code != 200 :
        print('🔴 Resource schema could not be updated. Dataset ID: {} - Resource ID: {}'.format(dataset_id, resource_id))
        
    return response.status_code == 200

# %%
#Function that deletes a schema (version) metadata on a resource
def delete_resource_schema(api_url, dataset_id, resource_id, initial_schema_name) :
    
    global HEADERS
    
    schema = {}
    
    try :
        url = api_url + 'datasets/{}/resources/{}/'.format(dataset_id, resource_id)
        r = requests.get(url, headers=HEADERS)
        extras = r.json()['extras']
    except :
        extras = {}
    
    extras['consolidation_schema:remove_schema'] = schema_name
    
    obj = {'schema': schema, 'extras': extras}
                
    url = api_url + 'datasets/{}/resources/{}/'.format(dataset_id, resource_id)
    response = requests.put(url, json=obj, headers=HEADERS)
    
    if response.status_code != 200 :
        print('🔴 Resource schema could not be deleted. Dataset ID: {} - Resource ID: {}'.format(dataset_id, resource_id))
    
    return response.status_code == 200

# %%
#Get the (list of) e-mail address(es) of the owner or of the admin(s) of the owner organization of a dataset
def get_owner_or_admin_mails(dataset_id, api_url) :
    r = requests.get(api_url + 'datasets/{}/'.format(dataset_id))
    r_dict = r.json()
    
    if r_dict['organization'] is not None :
        org_id = r_dict['organization']['id']
    else :
        org_id = None
    
    if r_dict['owner'] is not None :
        owner_id = r_dict['owner']['id']
    else :
        owner_id = None
    
    mails_type = None
    mails_list = []
    
    if org_id is not None :
        mails_type = 'organisation_admins'
        r_org = requests.get(api_url + 'organizations/{}/'.format(org_id))
        members_list = r_org.json()['members']
        for member in members_list :
            if member['role'] == 'admin' :
                user_id = member['user']['id']
                r_user = requests.get(api_url + 'users/{}/'.format(user_id), headers=HEADER)
                user_mail = r_user.json()['email']
                mails_list += [user_mail]
                
    else :
        if owner_id is not None :
            mails_type = 'owner'
            r_user = requests.get(api_url + 'users/{}/'.format(owner_id), headers=HEADER)
            user_mail = r_user.json()['email']
            mails_list += [user_mail]
    
    return (mails_type, mails_list)

# %%
#Function to send a e-mail
def send_email(subject, message, mail_from, mail_to, smtp_host, smtp_user, smtp_password):
    message = emails.html(html='<p>%s</p>' % message,
                        subject=subject,
                        mail_from=mail_from)
    smtp = {
        'host': smtp_host,
        'port': 587,
        'tls': True,
        'user': smtp_user,
        'password': smtp_password,
    }

    _ = message.send(to=mail_to, smtp=smtp)
    
    return _

# %%
#Function to post a comment on a dataset
def post_comment_on_dataset(dataset_id, title, comment, api_url) :
    
    global HEADER
    
    post_object = {
        'title':title,
        'comment' : comment,
        'subject': {'class': 'Dataset', 'id': dataset_id}
    }
    
    _ = requests.post(api_url + 'discussions/', json=post_object, headers=HEADER)
    
    return _

# %% [markdown]
# # Main code

# %% [markdown]
# ## Utils

# %%
consolidation_date_str = datetime.now().strftime('%Y%m%d')
print(consolidation_date_str)
# Out:
# 20211118

# %%
data_path = tmp_path / 'data'
data_path.mkdir(parents=True, exist_ok=True)

# %%
consolidated_data_path = tmp_path / 'consolidated_data'
consolidated_data_path.mkdir(parents=True, exist_ok=True)

# %%
ref_tables_path = tmp_path / 'ref_tables'
ref_tables_path.mkdir(parents=True, exist_ok=True)

# %%
report_tables_path = tmp_path / 'report_tables'
report_tables_path.mkdir(parents=True, exist_ok=True)

# %%
output_path = tmp_path / 'output'
output_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Loading schemas documentation and config

# %% [markdown]
# ### Schemas documentation

# %% [markdown]
# We keep **only table schemas**.

# %%
# Getting schemas list :

#Keeping track of schema info
schemas_report_dict = {}

schemas_catalogue_dict = requests.get(schemas_list_url).json()
print('Schema catalogue URL: {}'.format(schemas_catalogue_dict['$schema']))
print('Version: {}'.format(schemas_catalogue_dict['version']))

schemas_catalogue_list = [schema for schema in schemas_catalogue_dict['schemas'] if schema['schema_type'] == 'tableschema']
nb_schemas = len(schemas_catalogue_list)
print('Total number of schemas: {}'.format(nb_schemas))

for schema in schemas_catalogue_list :
    print('- {} ({} versions)'.format(schema['name'], len(schema['versions'])))
    schemas_report_dict[schema['name']] = {'nb_versions':len(schema['versions'])}
# Out:
# Schema catalogue URL: https://opendataschema.frama.io/catalog/schema-catalog.json
# Version: 1
# Total number of schemas: 24
# - etalab/schema-irve (7 versions)
# - etalab/schema-decp-dpa (1 versions)
# - scdl/catalogue (2 versions)
# - scdl/deliberations (6 versions)
# - scdl/equipements (2 versions)
# - scdl/subventions (3 versions)
# - etalab/schema-lieux-covoiturage (6 versions)
# - etalab/schema-stationnement (5 versions)
# - scdl/budget (1 versions)
# - arsante/schema-dae (3 versions)
# - NaturalSolutions/schema-arbre (4 versions)
# - etalab/schema-stationnement-cyclable (5 versions)
# - etalab/schema-inclusion-numerique (2 versions)
# - etalab/schema-hautes-remunerations (1 versions)
# - scdl/menus-collectifs (9 versions)
# - scdl/plats-menus-collectifs (4 versions)
# - MTES-MCT/acceslibre-schema (3 versions)
# - etalab/schema-sdirve (1 versions)
# - Archivistes75/registre_entrees (1 versions)
# - CEREMA/schema-arrete-circulation-marchandises (8 versions)
# - openmaraude/schema-stationstaxi (3 versions)
# - etalab/schema-vehicules-faibles-emissions-renouvellement-parc (2 versions)
# - datakode/schema-pei (1 versions)
# - etalab/schema-passage-a-niveau (1 versions)

# %% [markdown]
# ### Creating/updating config file with missing schemas

# %%
if os.path.exists(config_path) :
    with open(config_path, 'r') as f :
        config_dict = yaml.safe_load(f)
else :
    config_dict = {}
    
for schema in schemas_catalogue_list :
    if schema['name'] not in config_dict.keys() :
        add_schema_default_config(schema['name'], config_path)
        schemas_report_dict[schema['name']]['new_config_created'] = True
        print('{} - ➕ Schema {} added to config file.'.format(datetime.today(), schema['name']))
    else :
        schemas_report_dict[schema['name']]['new_config_created'] = False
        print('{} - 🆗 Schema {} already in config file.'.format(datetime.today(), schema['name']))
# Out:
# 2021-11-18 10:35:15.430134 - 🆗 Schema etalab/schema-irve already in config file.
# 2021-11-18 10:35:15.430354 - 🆗 Schema etalab/schema-decp-dpa already in config file.
# 2021-11-18 10:35:15.430398 - 🆗 Schema scdl/catalogue already in config file.
# 2021-11-18 10:35:15.430432 - 🆗 Schema scdl/deliberations already in config file.
# 2021-11-18 10:35:15.430464 - 🆗 Schema scdl/equipements already in config file.
# 2021-11-18 10:35:15.430497 - 🆗 Schema scdl/subventions already in config file.
# 2021-11-18 10:35:15.430541 - 🆗 Schema etalab/schema-lieux-covoiturage already in config file.
# 2021-11-18 10:35:15.430572 - 🆗 Schema etalab/schema-stationnement already in config file.
# 2021-11-18 10:35:15.430605 - 🆗 Schema scdl/budget already in config file.
# 2021-11-18 10:35:15.430637 - 🆗 Schema arsante/schema-dae already in config file.
# 2021-11-18 10:35:15.430672 - 🆗 Schema NaturalSolutions/schema-arbre already in config file.
# 2021-11-18 10:35:15.430704 - 🆗 Schema etalab/schema-stationnement-cyclable already in config file.
# 2021-11-18 10:35:15.431111 - 🆗 Schema etalab/schema-inclusion-numerique already in config file.
# 2021-11-18 10:35:15.431222 - 🆗 Schema etalab/schema-hautes-remunerations already in config file.
# 2021-11-18 10:35:15.431260 - 🆗 Schema scdl/menus-collectifs already in config file.
# 2021-11-18 10:35:15.431292 - 🆗 Schema scdl/plats-menus-collectifs already in config file.
# 2021-11-18 10:35:15.431323 - 🆗 Schema MTES-MCT/acceslibre-schema already in config file.
# 2021-11-18 10:35:15.431377 - 🆗 Schema etalab/schema-sdirve already in config file.
# 2021-11-18 10:35:15.431411 - 🆗 Schema Archivistes75/registre_entrees already in config file.
# 2021-11-18 10:35:15.431439 - 🆗 Schema CEREMA/schema-arrete-circulation-marchandises already in config file.
# 2021-11-18 10:35:15.431502 - 🆗 Schema openmaraude/schema-stationstaxi already in config file.
# 2021-11-18 10:35:15.431703 - 🆗 Schema etalab/schema-vehicules-faibles-emissions-renouvellement-parc already in config file.
# 2021-11-18 10:35:15.432134 - 🆗 Schema datakode/schema-pei already in config file.
# 2021-11-18 10:35:15.432167 - 🆗 Schema etalab/schema-passage-a-niveau already in config file.

# %% [markdown]
# **⚠️⚠️⚠️ EDIT CONFIG FILE IF NEEDED (especially for new schemas) ⚠️⚠️⚠️**
#
# Then, reload config file:

# %%
with open(config_path, 'r') as f :
    config_dict = yaml.safe_load(f)

# %% [markdown]
# ## Building reference tables (parsing and listing resources + Validata check)

# %%
# %%time
for schema_name in config_dict.keys() :
    
    print('{} - ℹ️ STARTING SCHEMA: {}'.format(datetime.now(), schema_name))
    
    #NEEDED PARAMETERS
    
    #Schema description and consolidation configuration
    schema_config = config_dict[schema_name]
    
    if schema_config['consolidate'] == True :
    
        #Schema official specification (in catalogue)
        schema_dict = get_schema_dict(schema_name, schemas_catalogue_list)

        #Datasets to exclude (from config)
        datasets_to_exclude = []
        if 'consolidated_dataset_id' in schema_config.keys() :
            datasets_to_exclude += [schema_config['consolidated_dataset_id']]
        if 'exclude_dataset_ids' in schema_config.keys() :
            if type(schema_config['exclude_dataset_ids']) == list :
                datasets_to_exclude += schema_config['exclude_dataset_ids']

        #Tags and search words to use to get resources that could match schema (from config)
        tags_list = []
        if 'tags' in schema_config.keys() :
            tags_list += schema_config['tags']

        search_words_list = []
        if 'search_words' in schema_config.keys() :
            search_words_list = schema_config['search_words']

        #Schema versions not to consolidate
        drop_versions = []
        if 'drop_versions' in schema_config.keys() :
            drop_versions += schema_config['drop_versions']
        
        schemas_report_dict[schema_name]['nb_versions_to_drop_in_config'] = len(drop_versions)

        #PARSING API TO GET ALL ELIGIBLE RESOURCES FOR CONSOLIDATION

        df_list = []

        #Listing resources by schema request
        df_schema = parse_api(schema_url_base.format(schema_name=schema_name))
        schemas_report_dict[schema_name]['nb_resources_found_by_schema'] = len(df_schema)
        if len(df_schema) > 0 :
            df_schema['resource_found_by'] = '1 - schema request'
            df_schema['initial_version_name'] = df_schema.apply(lambda row : get_resource_schema_version(row, api_url), axis=1)
            df_list += [df_schema]

        #Listing resources by tag requests
        schemas_report_dict[schema_name]['nb_resources_found_by_tags'] = 0
        for tag in tags_list : 
            df_tag = parse_api(tag_url_base.format(tag=tag))
            schemas_report_dict[schema_name]['nb_resources_found_by_tags'] += len(df_tag)
            if len(df_tag) > 0 :
                df_tag['resource_found_by'] = '2 - tag request'
                df_list += [df_tag]

        #Listing resources by search (keywords) requests
        schemas_report_dict[schema_name]['nb_resources_found_by_search_words'] = 0
        for search_word in search_words_list :
            df_search_word = parse_api(search_url_base.format(search_word=search_word))
            schemas_report_dict[schema_name]['nb_resources_found_by_search_words'] += len(df_search_word)
            if len(df_search_word) > 0 :
                df_search_word['resource_found_by'] = '3 - search request'
                df_list += [df_search_word]

        if len(df_list) > 0 :
            df = pd.concat(df_list, ignore_index=True)
            df = df[~(df['dataset_id'].isin(datasets_to_exclude))]
            df = df.sort_values('resource_found_by')
            df = df.drop_duplicates(subset=['resource_id'], keep='first')
            
            print('{} -- 🔢 {} resource(s) found for this schema.'.format(datetime.now(), len(df)))
            
            if 'initial_version_name' not in df.columns : # in case there is no resource found by schema request
                df['initial_version_name'] = np.nan

            #FOR EACH RESOURCE AND SCHEMA VERSION, CHECK IF RESOURCE MATCHES THE SCHEMA VERSION

            #Apply validata check for each version that is not explicitly dropped in config file
            version_names_list = []
            
            for version in schema_dict['versions'] :
                version_name = version['version_name']
                if version_name not in drop_versions :
                    schema_url = version['schema_url']
                    df['is_valid_v_{}'.format(version_name)] = df.apply(lambda row : is_validata_valid_row(row, schema_url), axis=1)
                    version_names_list += [version_name]
                    print('{} --- ☑️ Validata check done for version {}'.format(datetime.now(), version_name))
                else :
                    print('{} --- ❌ Version {} to drop according to config file'.format(datetime.now(), version_name))
            
            if len(version_names_list) > 0 :
                #Check if resources are at least matching one schema version (only those matching will be downloaded in next step)
                df['is_valid_one_version'] = sum([df['is_valid_v_{}'.format(version_name)] for version_name in version_names_list]) > 0
                schemas_report_dict[schema_name]['nb_valid_resources'] = df['is_valid_one_version'].sum()
                df = add_most_recent_valid_version(df)
                df.to_csv(os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_'))), index=False)
                print('{} -- ✅ Validata check done for {}.'.format(datetime.now(), schema_name))
            else :
                schemas_report_dict[schema_name]['nb_valid_resources'] = 0
                print('{} -- ❌ All possible versions for this schema were dropped by config file.'.format(datetime.now()))

        else :
            print('{} -- ⚠️ No resource found for this schema.'.format(datetime.now(), schema_name))
            
    else :
        print('{} -- ❌ Schema not to consolidate according to config file.'.format(datetime.now()))
# Out:
# 2021-11-18 10:35:30.019013 - ℹ️ STARTING SCHEMA: Archivistes75/registre_entrees
# 2021-11-18 10:35:30.019276 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019331 - ℹ️ STARTING SCHEMA: CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 10:35:30.019404 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019429 - ℹ️ STARTING SCHEMA: MTES-MCT/acceslibre-schema
# 2021-11-18 10:35:30.019592 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019615 - ℹ️ STARTING SCHEMA: NaturalSolutions/schema-arbre
# 2021-11-18 10:35:30.019629 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019642 - ℹ️ STARTING SCHEMA: arsante/schema-dae
# 2021-11-18 10:35:30.019661 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019756 - ℹ️ STARTING SCHEMA: datakode/schema-pei
# 2021-11-18 10:35:30.019803 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019836 - ℹ️ STARTING SCHEMA: etalab/schema-decp-dpa
# 2021-11-18 10:35:30.019869 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019896 - ℹ️ STARTING SCHEMA: etalab/schema-hautes-remunerations
# 2021-11-18 10:35:30.019929 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.019957 - ℹ️ STARTING SCHEMA: etalab/schema-inclusion-numerique
# 2021-11-18 10:35:30.020185 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:35:30.020234 - ℹ️ STARTING SCHEMA: etalab/schema-irve
# 2021-11-18 10:36:07.789464 -- 🔢 551 resource(s) found for this schema.
# 2021-11-18 10:36:07.789709 --- ❌ Version 1.0.0 to drop according to config file
# 2021-11-18 10:36:07.789743 --- ❌ Version 1.0.1 to drop according to config file
# 2021-11-18 10:36:07.789779 --- ❌ Version 1.0.2 to drop according to config file
# 2021-11-18 10:36:07.789804 --- ❌ Version 1.0.3 to drop according to config file
# 2021-11-18 10:36:07.789890 --- ❌ Version 2.0.0 to drop according to config file
# 2021-11-18 10:36:07.789958 --- ❌ Version 2.0.1 to drop according to config file
# 2021-11-18 10:36:55.004177 ---- 🔴 Could not make JSON from validata report for resource: https://static.data.gouv.fr/resources/irve-eborn-20201211/20210818-171836/irve-eborn-20210701.csv
# 2021-11-18 10:38:28.038828 ---- 🔴 No info in validata report for resource: https://static.data.gouv.fr/resources/caracteristiques-des-points-de-charge-pour-vehicules-electriques-electric-55-charging-ouverts-au-public/20200814-151629/irve-e55c-ajourle.14.08.20.csv
# 2021-11-18 10:38:28.862009 ---- 🔴 No info in validata report for resource: https://static.data.gouv.fr/resources/irve-sied70-recensement-et-information/20190228-173321/irve-sied70-20190228.csv
# 2021-11-18 10:39:04.841267 ---- 🔴 No info in validata report for resource: https://static.data.gouv.fr/resources/premier-export-irve-zeborne-mobility-services-fev2021/20210211-153735/export-irve-data-gouv-v1-11fev21.csv
# 2021-11-18 10:41:56.503578 ---- 🔴 No info in validata report for resource: https://static.data.gouv.fr/resources/infrastructures-de-recharge-rapide-pour-vehicules-electriques-organisation-chargepoly/20211112-163310/data.csv
# 2021-11-18 10:42:59.682116 ---- 🔴 No info in validata report for resource: https://data.seineouest.fr/explore/dataset/reseau-de-bornes-de-recharge-pour-vehicule-electrique/download?format=csv&timezone=Europe/Berlin&use_labels_for_header=false
# 2021-11-18 10:43:22.580582 ---- 🔴 No info in validata report for resource: https://sdem.opendatasoft.com/explore/dataset/25560110600024_bornes-de-recharge-de-vehicules-electriques-irve/download?format=csv&timezone=Europe/Berlin&use_labels_for_header=false
# 2021-11-18 10:45:03.767169 ---- 🔴 No info in validata report for resource: https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-26/20210913-143231/bornes-rse01.csv
# 2021-11-18 10:45:58.011387 ---- 🔴 No info in validata report for resource: https://gpseo.opendatasoft.com/explore/dataset/infrastructures_de_recharge_vehicules_electriques_epone/download?format=csv&timezone=Europe/Berlin&use_labels_for_header=false
# 2021-11-18 10:46:19.754834 ---- 🔴 No info in validata report for resource: https://data.orleans-metropole.fr/explore/dataset/irve-alize-liberte-orleans-metropole/download?format=csv&timezone=Europe/Berlin&use_labels_for_header=false
# 2021-11-18 10:47:29.221587 ---- 🔴 No info in validata report for resource: https://opendata.reseaux-energies.fr/explore/dataset/conso-ve-sap/download?format=csv&timezone=Europe/Berlin&use_labels_for_header=false
# 2021-11-18 10:47:31.804604 --- ☑️ Validata check done for version 2.0.2
# 2021-11-18 10:47:31.831763 -- ✅ Validata check done for etalab/schema-irve.
# 2021-11-18 10:47:31.831982 - ℹ️ STARTING SCHEMA: etalab/schema-lieux-covoiturage
# 2021-11-18 10:47:31.832005 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832021 - ℹ️ STARTING SCHEMA: etalab/schema-passage-a-niveau
# 2021-11-18 10:47:31.832105 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832166 - ℹ️ STARTING SCHEMA: etalab/schema-sdirve
# 2021-11-18 10:47:31.832270 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832306 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement
# 2021-11-18 10:47:31.832338 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832411 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement-cyclable
# 2021-11-18 10:47:31.832459 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832498 - ℹ️ STARTING SCHEMA: etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 10:47:31.832538 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832609 - ℹ️ STARTING SCHEMA: openmaraude/schema-stationstaxi
# 2021-11-18 10:47:31.832632 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832649 - ℹ️ STARTING SCHEMA: scdl/budget
# 2021-11-18 10:47:31.832665 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832684 - ℹ️ STARTING SCHEMA: scdl/catalogue
# 2021-11-18 10:47:31.832704 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832719 - ℹ️ STARTING SCHEMA: scdl/deliberations
# 2021-11-18 10:47:31.832734 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832750 - ℹ️ STARTING SCHEMA: scdl/equipements
# 2021-11-18 10:47:31.832767 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832790 - ℹ️ STARTING SCHEMA: scdl/menus-collectifs
# 2021-11-18 10:47:31.832807 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832822 - ℹ️ STARTING SCHEMA: scdl/plats-menus-collectifs
# 2021-11-18 10:47:31.832842 -- ❌ Schema not to consolidate according to config file.
# 2021-11-18 10:47:31.832856 - ℹ️ STARTING SCHEMA: scdl/subventions
# 2021-11-18 10:47:31.832871 -- ❌ Schema not to consolidate according to config file.
# CPU times: user 22.4 s, sys: 2.14 s, total: 24.5 s
# Wall time: 12min 1s

# %% [markdown]
# ## Downloading valid data

# %% [markdown]
# We download only data that is valid for at least one version of the schema.

# %%
# %%time
for schema_name in config_dict.keys() :
    
    print('{} - ℹ️ STARTING SCHEMA: {}'.format(datetime.now(), schema_name))
    
    ref_table_path = os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_')))
    
    if os.path.exists(ref_table_path) :
        df_ref = pd.read_csv(ref_table_path)
        df_ref['is_downloaded'] = False
        
        if len(df_ref[df_ref['is_valid_one_version'] == True]) > 0 :
        
            schema_data_path = Path(data_path) / schema_name.replace('/','_')
            schema_data_path.mkdir(exist_ok=True)

            for index,row in df_ref[df_ref['is_valid_one_version'] == True].iterrows():
                rurl = row['resource_url']
                r = requests.get(rurl, allow_redirects=True)
                
                if r.status_code == 200 :
                    p = Path(schema_data_path) / row['dataset_slug']
                    p.mkdir(exist_ok=True)
                    written_filename = '{}.csv'.format(row['resource_id'])

                    with open('{}/{}'.format(p, written_filename), 'wb') as f:
                        f.write(r.content)
                    
                    df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'is_downloaded'] = True
                    
                    print('{} --- ⬇️✅ downloaded file [{}] {}'.format(datetime.now(), row['resource_title'], rurl))
                else :
                    print('{} --- ⬇️❌ File could not be downloaded: [{}] {}'.format(datetime.now(), row['resource_title'], rurl))
                    
        else :
            print('{} -- ⚠️ No valid resource for this schema'.format(datetime.now()))
            
        df_ref.to_csv(ref_table_path, index=False)
    
    else :
        print('{} -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).'.format(datetime.now()))
# Out:
# 2021-11-18 10:48:38.761925 - ℹ️ STARTING SCHEMA: Archivistes75/registre_entrees
# 2021-11-18 10:48:38.763316 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.763880 - ℹ️ STARTING SCHEMA: CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 10:48:38.764205 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.764320 - ℹ️ STARTING SCHEMA: MTES-MCT/acceslibre-schema
# 2021-11-18 10:48:38.764629 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.764952 - ℹ️ STARTING SCHEMA: NaturalSolutions/schema-arbre
# 2021-11-18 10:48:38.765284 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.765352 - ℹ️ STARTING SCHEMA: arsante/schema-dae
# 2021-11-18 10:48:38.765722 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.765805 - ℹ️ STARTING SCHEMA: datakode/schema-pei
# 2021-11-18 10:48:38.765960 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.766205 - ℹ️ STARTING SCHEMA: etalab/schema-decp-dpa
# 2021-11-18 10:48:38.766601 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.766675 - ℹ️ STARTING SCHEMA: etalab/schema-hautes-remunerations
# 2021-11-18 10:48:38.766768 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.766863 - ℹ️ STARTING SCHEMA: etalab/schema-inclusion-numerique
# 2021-11-18 10:48:38.767358 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:38.767608 - ℹ️ STARTING SCHEMA: etalab/schema-irve
# 2021-11-18 10:48:38.915881 --- ⬇️✅ downloaded file [irve-data.gouv.saint-georges-du-bois.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-en-itinerance-publique-1/20211025-103032/irve-data.gouv.saint-georges-du-bois.csv
# 2021-11-18 10:48:39.017262 --- ⬇️✅ downloaded file [Monfichier_NF001019] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210923-105802/data.csv
# 2021-11-18 10:48:39.102883 --- ⬇️✅ downloaded file [Bornes IRVE Bulle de Linge] https://static.data.gouv.fr/resources/bornes-irve-bulle-de-linge/20210810-005110/bulle-de-linge-irve.csv
# 2021-11-18 10:48:39.231971 --- ⬇️✅ downloaded file [Monfichier_NF039295] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210730-145157/data.csv
# 2021-11-18 10:48:39.332053 --- ⬇️✅ downloaded file [Monfichier_NF059786] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-1/20210715-151612/data.csv
# 2021-11-18 10:48:39.431199 --- ⬇️✅ downloaded file [SAS-Sabo.CVS] https://static.data.gouv.fr/resources/borne-de-recharge-de-la-sas-sabo/20210517-162554/data.csv
# 2021-11-18 10:48:39.535446 --- ⬇️✅ downloaded file [irve-grandlyon-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-izivia-grand-lyon/20211102-090852/irve-grandlyon-20211102.csv
# 2021-11-18 10:48:39.613399 --- ⬇️✅ downloaded file [Monfichier_NF080183] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210730-144547/data.csv
# 2021-11-18 10:48:39.700783 --- ⬇️✅ downloaded file [Monfichier_NF068069] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210730-143104/data.csv
# 2021-11-18 10:48:39.787575 --- ⬇️✅ downloaded file [Monfichier_NF068069] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210730-143103/data.csv
# 2021-11-18 10:48:39.868882 --- ⬇️✅ downloaded file [HotelMacon.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-inouid-smart-mobility/20210730-165005/data.csv
# 2021-11-18 10:48:39.953709 --- ⬇️✅ downloaded file [GARAGE ZAWIEJA] https://static.data.gouv.fr/resources/garage-zawieja/20210624-143905/data.csv
# 2021-11-18 10:48:40.043412 --- ⬇️✅ downloaded file [Fichier IRVE Borne Leclerc Marmande] https://static.data.gouv.fr/resources/e-leclerc-marmande/20210615-105609/data.csv
# 2021-11-18 10:48:40.150890 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide/20210715-120952/data.csv
# 2021-11-18 10:48:40.228887 --- ⬇️✅ downloaded file [Monfichier_NF007060] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide/20210715-122351/data.csv
# 2021-11-18 10:48:40.302566 --- ⬇️✅ downloaded file [Monfichier_NF010132] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide/20210715-140046/data.csv
# 2021-11-18 10:48:40.428703 --- ⬇️✅ downloaded file [Monfichier_NF050462] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide/20210715-141656/data.csv
# 2021-11-18 10:48:40.520706 --- ⬇️✅ downloaded file [Monfichier_NF058543] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide/20210715-145347/data.csv
# 2021-11-18 10:48:40.607051 --- ⬇️✅ downloaded file [Monfichier_NF078171] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-4/20210715-154841/data.csv
# 2021-11-18 10:48:40.701559 --- ⬇️✅ downloaded file [Monfichier_NF077241] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-4/20210730-144039/data.csv
# 2021-11-18 10:48:40.783866 --- ⬇️✅ downloaded file [Monfichier_NF080162] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210715-160304/data.csv
# 2021-11-18 10:48:40.870383 --- ⬇️✅ downloaded file [Monfichier_NF050499] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210730-141601/data.csv
# 2021-11-18 10:48:40.958472 --- ⬇️✅ downloaded file [Monfichier_NF078238] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-5/20210730-142326/data.csv
# 2021-11-18 10:48:41.058731 --- ⬇️✅ downloaded file [CSV Data.gouv Hotel Macon] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-inouid-smart-mobility/20210730-164241/data.csv
# 2021-11-18 10:48:41.248879 --- ⬇️✅ downloaded file [irve-mobisdec-20210823.csv] https://static.data.gouv.fr/resources/bornes-de-recharge-mobisdec-syndicat-departemental-denergies-du-calvados/20210823-145421/irve-mobisdec-20210823.csv
# 2021-11-18 10:48:41.361115 --- ⬇️✅ downloaded file [IRVE_sdesm_20210609.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-ecocharge77/20210609-175423/data.csv
# 2021-11-18 10:48:41.475772 --- ⬇️✅ downloaded file [Infrastructures de recharge pour véhicules électriques (organisation MEA ENERGIES)] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-mea-energies/20210806-163155/data.csv
# 2021-11-18 10:48:41.589029 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-21/20210715-201203/data.csv
# 2021-11-18 10:48:41.678563 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-21/20210715-201201/data.csv
# 2021-11-18 10:48:41.738307 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-21/20210715-201201/data.csv
# 2021-11-18 10:48:41.857493 --- ⬇️✅ downloaded file [Electriox Groupe IRVE Genay] https://static.data.gouv.fr/resources/electriox-groupe-irve-genay/20210618-173918/data.csv
# 2021-11-18 10:48:41.945789 --- ⬇️✅ downloaded file [AVOMARKS] https://static.data.gouv.fr/resources/mes-bornes/20210623-181651/data.csv
# 2021-11-18 10:48:42.047422 --- ⬇️✅ downloaded file [F3C Baume DATA GOUV] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-properphi/20210719-130807/data.csv
# 2021-11-18 10:48:42.141806 --- ⬇️✅ downloaded file [Monfichier MBC] https://static.data.gouv.fr/resources/borne-eleec-publique/20211014-164234/data.csv
# 2021-11-18 10:48:42.252381 --- ⬇️✅ downloaded file [BORNE ROUXEL MARINE] https://static.data.gouv.fr/resources/borne-eleec-publique/20211112-093832/data.csv
# 2021-11-18 10:48:42.362205 --- ⬇️✅ downloaded file [BORNE PERRY 1/2] https://static.data.gouv.fr/resources/borne-eleec-publique/20211112-104716/data.csv
# 2021-11-18 10:48:42.472947 --- ⬇️✅ downloaded file [BORNE PERRY 2/2] https://static.data.gouv.fr/resources/borne-eleec-publique/20211112-105411/data.csv
# 2021-11-18 10:48:42.611640 --- ⬇️✅ downloaded file [AQUA LOISIRS XEV200C] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-infelec/20210705-160322/data.csv
# 2021-11-18 10:48:42.691003 --- ⬇️✅ downloaded file [SAS Lujasy] https://static.data.gouv.fr/resources/borne-de-recharge-de-la-sas-lujasy/20210630-130817/data.csv
# 2021-11-18 10:48:42.784468 --- ⬇️✅ downloaded file [Hôtel Macchi] https://static.data.gouv.fr/resources/borne-de-recharge-de-lhotel-macchi/20210630-130047/data.csv
# 2021-11-18 10:48:42.890394 --- ⬇️✅ downloaded file [bornes-irve-sogestran.csv] https://static.data.gouv.fr/resources/bornes-irve-sogestran/20210721-111132/bornes-irve-sogestran.csv
# 2021-11-18 10:48:42.979064 --- ⬇️✅ downloaded file [BBJ.csv] https://static.data.gouv.fr/resources/borne-de-recharge-1/20210518-121750/data.csv
# 2021-11-18 10:48:43.081740 --- ⬇️✅ downloaded file [Leclerc Mimizan.csv] https://static.data.gouv.fr/resources/borne-de-recharge-1/20210518-150007/data.csv
# 2021-11-18 10:48:43.197904 --- ⬇️✅ downloaded file [Bornes de recharges GAMBUS et PHA] https://static.data.gouv.fr/resources/installation-de-bornes-de-recharges-sur-cavaillon/20210511-160232/data.csv
# 2021-11-18 10:48:43.294089 --- ⬇️✅ downloaded file [Borne de charge IRVE ALU GRANON] https://static.data.gouv.fr/resources/installation-de-bornes-de-recharges-sur-cavaillon/20210617-144920/data.csv
# 2021-11-18 10:48:43.399435 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/installation-de-bornes-de-recharges-sur-cavaillon/20210810-151828/data.csv
# 2021-11-18 10:48:43.498916 --- ⬇️✅ downloaded file [PERRUT] https://static.data.gouv.fr/resources/installation-de-bornes-de-recharges-sur-cavaillon/20211007-151135/data.csv
# 2021-11-18 10:48:43.602739 --- ⬇️✅ downloaded file [Monfichier_NF076523] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-2/20210715-152527/data.csv
# 2021-11-18 10:48:43.741692 --- ⬇️✅ downloaded file [irve-de-lepervanche-jardins-de-la-sud-20210802.csv] https://static.data.gouv.fr/resources/les-jardins-de-la-sud/20210802-115644/irve-de-lepervanche-jardins-de-la-sud-20210802.csv
# 2021-11-18 10:48:43.846735 --- ⬇️✅ downloaded file [Monfichier.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-22/20210721-162941/data.csv
# 2021-11-18 10:48:43.967778 --- ⬇️✅ downloaded file [Monfichier.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-22/20210723-133435/data.csv
# 2021-11-18 10:48:44.053871 --- ⬇️✅ downloaded file [AEV-SATORIZ GRENOBLE ROCADE-DATA.GOUV] https://static.data.gouv.fr/resources/satoriz-grenoble-rocde/20210802-073357/data.csv
# 2021-11-18 10:48:44.179742 --- ⬇️✅ downloaded file [DATA GOUV - Borne de recharge Coprodex Saint-Avold] https://static.data.gouv.fr/resources/borne-de-recharge-coprodex-saint-avold/20210622-133631/data.csv
# 2021-11-18 10:48:44.275551 --- ⬇️✅ downloaded file [ETANCHEITE PARTICULIERS ET INDUSTRIES] https://static.data.gouv.fr/resources/etancheite-particuliers-et-industries/20210622-164547/data.csv
# 2021-11-18 10:48:44.405956 --- ⬇️✅ downloaded file [Bornes_Rossini_20-7-21] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-rossini-energy/20210720-155831/data.csv
# 2021-11-18 10:48:44.511955 --- ⬇️✅ downloaded file [Bornes_Rossini_9/11/21] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-rossini-energy/20211109-150750/data.csv
# 2021-11-18 10:48:44.629083 --- ⬇️✅ downloaded file [Bornes IRVE Syndicat Intercommunal d'Electricité et de Gaz de l'Eure] https://static.data.gouv.fr/resources/bornes-irve-syndicat-intercommunal-delectricite-et-de-gaz-de-leure/20210629-184259/irve-siege27-20200113.xlsx-irve-siege27-new-format-20210610-.csv
# 2021-11-18 10:48:44.723416 --- ⬇️✅ downloaded file [SERTITUDE] https://static.data.gouv.fr/resources/sertitude-1/20210622-154629/data.csv
# 2021-11-18 10:48:44.838916 --- ⬇️✅ downloaded file [irve-tente-20210525.csv] https://static.data.gouv.fr/resources/irve-tente/20210713-152818/irve-tente-20210525.csv
# 2021-11-18 10:48:44.971474 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-1/20210712-185003/data.csv
# 2021-11-18 10:48:45.075115 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-21/20210715-201200/data.csv
# 2021-11-18 10:48:45.167165 --- ⬇️✅ downloaded file [etalab-schema-irve-2021-05-10t18-35-31.014z.csv] https://static.data.gouv.fr/resources/borne-recharge-hotel-la-javotte/20210510-210129/etalab-schema-irve-2021-05-10t18-35-31.014z.csv
# 2021-11-18 10:48:45.269992 --- ⬇️✅ downloaded file [Leclerc Express Labouheyre.csv] https://static.data.gouv.fr/resources/borne-de-recharge-1/20210518-161537/data.csv
# 2021-11-18 10:48:45.381218 --- ⬇️✅ downloaded file [Centre Auto Leclerc Langon] https://static.data.gouv.fr/resources/borne-de-recharge-1/20210719-175333/data.csv
# 2021-11-18 10:48:45.489409 --- ⬇️✅ downloaded file [Leclerc Biars] https://static.data.gouv.fr/resources/borne-de-recharge-1/20210730-113648/data.csv
# 2021-11-18 10:48:45.581804 --- ⬇️✅ downloaded file [Leclerc Mios] https://static.data.gouv.fr/resources/borne-de-recharge-1/20210802-103955/data.csv
# 2021-11-18 10:48:45.678973 --- ⬇️✅ downloaded file [liste publique places 12 06 2021.csv] https://static.data.gouv.fr/resources/liste-place-de-recharge/20210612-152004/data.csv
# 2021-11-18 10:48:45.773643 --- ⬇️✅ downloaded file [SV data.gouv quincy.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-23/20210729-220255/data.csv
# 2021-11-18 10:48:45.884557 --- ⬇️✅ downloaded file [FXM EVENTS] https://static.data.gouv.fr/resources/fxm-events/20210803-141049/data.csv
# 2021-11-18 10:48:46.005746 --- ⬇️✅ downloaded file [Monfichier_NF059964] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-charge-rapide-3/20210715-154202/data.csv
# 2021-11-18 10:48:46.101262 --- ⬇️✅ downloaded file [irve-overchem-20210628.csv] https://static.data.gouv.fr/resources/overchem/20210713-153305/irve-overchem-20210628.csv
# 2021-11-18 10:48:46.186403 --- ⬇️✅ downloaded file [Monfichier IRVE Leclerc Drive Anglet] https://static.data.gouv.fr/resources/e-leclerc-drive-anglet/20210615-121154/data.csv
# 2021-11-18 10:48:46.271949 --- ⬇️✅ downloaded file [SDIRVE SDE23] https://static.data.gouv.fr/resources/bornes-sde-creuse/20210621-101944/data.csv
# 2021-11-18 10:48:46.369203 --- ⬇️✅ downloaded file [LA FERME DE LA MOTTE] https://static.data.gouv.fr/resources/la-ferme-de-la-motte/20210622-162055/data.csv
# 2021-11-18 10:48:46.457975 --- ⬇️✅ downloaded file [Réseau MOBILYGREEN] https://static.data.gouv.fr/resources/reseau-de-bornes-de-recharge-mobilygreen/20211028-145447/data.csv
# 2021-11-18 10:48:46.568707 --- ⬇️✅ downloaded file [irve-sigeif-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-sigeif-1/20211102-090856/irve-sigeif-20211102.csv
# 2021-11-18 10:48:46.687253 --- ⬇️✅ downloaded file [datagouvhotelstwalfrid.csv] https://static.data.gouv.fr/resources/borne-de-charge-hotel-saint-walfrid/20210609-160233/data.csv
# 2021-11-18 10:48:46.803063 --- ⬇️✅ downloaded file [SAP LABS FRANCE] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-abe-electricite/20210704-223716/data.csv
# 2021-11-18 10:48:46.913411 --- ⬇️✅ downloaded file [data-1-.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-waat/20210930-115615/data-1-.csv
# 2021-11-18 10:48:46.998379 --- ⬇️✅ downloaded file [Bornes IRVE DEBELEC] https://static.data.gouv.fr/resources/bornes-irve-debelec/20211004-142359/datagouv-irve-debelec-2021-10-04-feuille-1.csv
# 2021-11-18 10:48:47.095602 --- ⬇️✅ downloaded file [data-gouv-rencontre-handi.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-32/20211102-110128/data.csv
# 2021-11-18 10:48:47.188142 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/bornes-de-recharge-de-vehicules-electriques-hotel-mont-blanc-st-pierre-en-faucigny/20211018-131432/data.csv
# 2021-11-18 10:48:47.303266 --- ⬇️✅ downloaded file [parc_mobive_33_2021_10_08] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-syndicat-departemental-denergie-electrique-de-la-gironde/20211008-173904/data.csv
# 2021-11-18 10:48:47.390805 --- ⬇️✅ downloaded file [Orchidées Data Gouv.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-30/20211005-153912/data.csv
# 2021-11-18 10:48:47.494094 --- ⬇️✅ downloaded file [irve-smoys-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-smoys/20211102-090845/irve-smoys-20211102.csv
# 2021-11-18 10:48:47.601488 --- ⬇️✅ downloaded file [irve-unibail-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-unibail/20211102-090851/irve-unibail-20211102.csv
# 2021-11-18 10:48:47.698337 --- ⬇️✅ downloaded file [irve-froth-20211026] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-froth/20211026-160757/data.csv
# 2021-11-18 10:48:47.796940 --- ⬇️✅ downloaded file [Monfichier.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-waat/20210805-111910/data.csv
# 2021-11-18 10:48:47.893710 --- ⬇️✅ downloaded file [adam.csv] https://static.data.gouv.fr/resources/bornes-de-charge-adam-sas/20210926-193632/adam.csv
# 2021-11-18 10:48:48.033219 --- ⬇️✅ downloaded file [Monfichier.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-25/20210906-092711/data.csv
# 2021-11-18 10:48:48.140849 --- ⬇️✅ downloaded file [JOUE LES TOURS.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-herve-thermique-joue-les-tours/20210907-110957/data.csv
# 2021-11-18 10:48:48.255095 --- ⬇️✅ downloaded file [DACIA RONCQ] https://static.data.gouv.fr/resources/dacia-roncq/20211013-134939/data.csv
# 2021-11-18 10:48:48.364380 --- ⬇️✅ downloaded file [LELIEUR FERNAND] https://static.data.gouv.fr/resources/lelieur-fernand/20211007-170746/data.csv
# 2021-11-18 10:48:48.454131 --- ⬇️✅ downloaded file [irve-sixt-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-sixt/20211102-090849/irve-sixt-20211102.csv
# 2021-11-18 10:48:48.547718 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-k-helios/20211018-150740/data.csv
# 2021-11-18 10:48:48.670592 --- ⬇️✅ downloaded file [VOLSWAGEN] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-k-helios/20211028-090341/data.csv
# 2021-11-18 10:48:48.773416 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-36/20211019-174137/data.csv
# 2021-11-18 10:48:48.877155 --- ⬇️✅ downloaded file [IRVE_VIRTA_20210827.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-virta/20210827-132629/data.csv
# 2021-11-18 10:48:48.969923 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-zeenco/20211028-174452/data.csv
# 2021-11-18 10:48:49.077309 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-zeenco/20210924-123141/data.csv
# 2021-11-18 10:48:49.193244 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-zeenco/20210923-181126/data.csv
# 2021-11-18 10:48:49.368007 --- ⬇️✅ downloaded file [irve-wiiiz-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-wiiiz/20211102-090850/irve-wiiiz-20211102.csv
# 2021-11-18 10:48:49.470349 --- ⬇️✅ downloaded file [2F Production] https://static.data.gouv.fr/resources/irve-2f-production/20210923-084311/data.csv
# 2021-11-18 10:48:49.606233 --- ⬇️✅ downloaded file [SCI CD] https://static.data.gouv.fr/resources/sci-cd/20211116-093024/data.csv
# 2021-11-18 10:48:49.702199 --- ⬇️✅ downloaded file [Bornes IRVE Brasserie Castelain] https://static.data.gouv.fr/resources/bornes-irve-brasserie-castelain/20211004-140304/data-gouv-irve-2021-09-17.csv
# 2021-11-18 10:48:49.797632 --- ⬇️✅ downloaded file [Infrastructures de recharge pour véhicules électriques (organisation MEA ENERGIES)] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-mea-energies-1/20210921-140138/data.csv
# 2021-11-18 10:48:49.936217 --- ⬇️✅ downloaded file [irve-shell-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-shell/20211102-090844/irve-shell-20211102.csv
# 2021-11-18 10:48:50.035431 --- ⬇️✅ downloaded file [DATAGOUV CSV F3C ALBON.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-properphi-1/20210809-122755/data.csv
# 2021-11-18 10:48:50.147328 --- ⬇️✅ downloaded file [BIG MAT] https://static.data.gouv.fr/resources/big-mat/20211110-160640/data.csv
# 2021-11-18 10:48:50.303811 --- ⬇️✅ downloaded file [irve-ouestcharge35-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-ouest-charge-35/20211102-090847/irve-ouestcharge35-20211102.csv
# 2021-11-18 10:48:50.440069 --- ⬇️✅ downloaded file [SOLLIX] https://static.data.gouv.fr/resources/sollix/20211008-095850/data.csv
# 2021-11-18 10:48:50.564088 --- ⬇️✅ downloaded file [RENAULT HAZEBROUCK] https://static.data.gouv.fr/resources/renault-hazebrouck/20211011-140043/data.csv
# 2021-11-18 10:48:50.669365 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/borne-de-recharge-2/20211109-212246/data.csv
# 2021-11-18 10:48:50.778960 --- ⬇️✅ downloaded file [Fasthôtel Toulouse - Blagnac aéroport] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-autorecharge-1/20210820-180625/data.csv
# 2021-11-18 10:48:50.882710 --- ⬇️✅ downloaded file [STATIONS-E BORNES IRVE] https://static.data.gouv.fr/resources/stations-e-bornes-charge-irve/20211008-171639/data.csv
# 2021-11-18 10:48:50.984268 --- ⬇️✅ downloaded file [ANS COM] https://static.data.gouv.fr/resources/ans-com/20210901-091115/data.csv
# 2021-11-18 10:48:51.113807 --- ⬇️✅ downloaded file [GOOD KING] https://static.data.gouv.fr/resources/good-king/20210906-173433/data.csv
# 2021-11-18 10:48:51.261252 --- ⬇️✅ downloaded file [irve-syder-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-syder/20211102-090847/irve-syder-20211102.csv
# 2021-11-18 10:48:51.375509 --- ⬇️✅ downloaded file [ZEENCO] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-zeenco/20210920-123706/data.csv
# 2021-11-18 10:48:51.478391 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-lumiin/20211109-213406/data.csv
# 2021-11-18 10:48:51.591241 --- ⬇️✅ downloaded file [DACIA BEAURAINS] https://static.data.gouv.fr/resources/dacia-beaurains/20211112-151400/data.csv
# 2021-11-18 10:48:51.692515 --- ⬇️✅ downloaded file [Monfichier.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-energie-eure-et-loir/20210923-164456/data.csv
# 2021-11-18 10:48:51.800113 --- ⬇️✅ downloaded file [210830-irve-driveco.csv] https://static.data.gouv.fr/resources/liste-des-bornes-de-recharge-ouvertes-au-public/20210830-114846/210830-irve-driveco.csv
# 2021-11-18 10:48:51.902439 --- ⬇️✅ downloaded file [irve-cps-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-cps/20211102-090855/irve-cps-20211102.csv
# 2021-11-18 10:48:52.053386 --- ⬇️✅ downloaded file [irve-levaparc-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-levaparc/20211102-090851/irve-levaparc-20211102.csv
# 2021-11-18 10:48:52.178176 --- ⬇️✅ downloaded file [irve-arcachon-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-arcachon/20211102-090900/irve-arcachon-20211102.csv
# 2021-11-18 10:48:52.307320 --- ⬇️✅ downloaded file [irve-rt78-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-rt78/20211102-090845/irve-rt78-20211102.csv
# 2021-11-18 10:48:52.402648 --- ⬇️✅ downloaded file [irve-garenne-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-garenne-colombe/20211102-090900/irve-garenne-20211102.csv
# 2021-11-18 10:48:52.538484 --- ⬇️✅ downloaded file [irve-lhsm-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-lhsm/20211102-090859/irve-lhsm-20211102.csv
# 2021-11-18 10:48:52.652689 --- ⬇️✅ downloaded file [irve-mobisdec-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-mobisdec/20211102-090854/irve-mobisdec-20211102.csv
# 2021-11-18 10:48:52.798851 --- ⬇️✅ downloaded file [irve-data.gouv.incroyable.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-en-itinerance-publique-1/20211001-122717/irve-data.gouv.incroyable.csv
# 2021-11-18 10:48:52.909642 --- ⬇️✅ downloaded file [irve-data.gouv.fontenelles.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-en-itinerance-publique-1/20211022-111152/irve-data.gouv.fontenelles.csv
# 2021-11-18 10:48:53.014754 --- ⬇️✅ downloaded file [irve-data.gouv.patte-d-oie.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-en-itinerance-publique-1/20211022-111621/irve-data.gouv.patte-d-oie.csv
# 2021-11-18 10:48:53.101230 --- ⬇️✅ downloaded file [irve-data.gouv.bois-joli.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-en-itinerance-publique-1/20211022-112626/irve-data.gouv.bois-joli.csv
# 2021-11-18 10:48:53.206892 --- ⬇️✅ downloaded file [irve-mobivesydec40-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-sydec-40-irve-mobive/20211102-090854/irve-mobivesydec40-20211102.csv
# 2021-11-18 10:48:53.378286 --- ⬇️✅ downloaded file [irve-mobivesdepa64-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-sdepa-64-irve-mobive/20211102-090847/irve-mobivesdepa64-20211102.csv
# 2021-11-18 10:48:53.578676 --- ⬇️✅ downloaded file [irve-mobivesdeg16-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-sdeg-16-irve-mobive/20211102-090848/irve-mobivesdeg16-20211102.csv
# 2021-11-18 10:48:53.737082 --- ⬇️✅ downloaded file [IRVE_SOREGIES_20210924.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-soregies/20210924-194623/data.csv
# 2021-11-18 10:48:53.853709 --- ⬇️✅ downloaded file [SCI 35 RUE DE ROUBAIX] https://static.data.gouv.fr/resources/sci-35-rue-de-roubaix/20211117-171054/data.csv
# 2021-11-18 10:48:53.954286 --- ⬇️✅ downloaded file [Monfichier.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-37/20211110-162806/data.csv
# 2021-11-18 10:48:54.089166 --- ⬇️✅ downloaded file [SC FRANETTI] https://static.data.gouv.fr/resources/sc-franetti/20211112-093029/data.csv
# 2021-11-18 10:48:54.225523 --- ⬇️✅ downloaded file [irve-iziviaexpress-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-izivia-express/20211102-090855/irve-iziviaexpress-20211102.csv
# 2021-11-18 10:48:54.327023 --- ⬇️✅ downloaded file [data-1-.csv] https://static.data.gouv.fr/resources/bornes-de-recharges/20210902-223245/data-1-.csv
# 2021-11-18 10:48:54.428870 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/bornes-de-recharges/20211109-212923/data.csv
# 2021-11-18 10:48:54.530908 --- ⬇️✅ downloaded file [2021-07-01-patrimoine-public-bs.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-en-itinerance-publique/20210702-115957/2021-07-01-patrimoine-public-bs.csv
# 2021-11-18 10:48:54.637545 --- ⬇️✅ downloaded file [irve-mobivesde24-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-sde-24-irve-mobive/20211102-090846/irve-mobivesde24-20211102.csv
# 2021-11-18 10:48:54.792342 --- ⬇️✅ downloaded file [irve-mobivete47-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-te-47-irve-mobive/20211102-090856/irve-mobivete47-20211102.csv
# 2021-11-18 10:48:54.921071 --- ⬇️✅ downloaded file [irve-mobivefdee19-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-fdee-19-irve-mobive/20211102-090849/irve-mobivefdee19-20211102.csv
# 2021-11-18 10:48:55.058700 --- ⬇️✅ downloaded file [irve-mobivesdeeg33-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-sdeeg-33-irve-mobive/20211102-090858/irve-mobivesdeeg33-20211102.csv
# 2021-11-18 10:48:55.194698 --- ⬇️✅ downloaded file [irve-mobivesdeer17-20211102.csv] https://static.data.gouv.fr/resources/bornes-de-recharges-reseau-mobive-sdeer-17-irve-mobive/20211102-090857/irve-mobivesdeer17-20211102.csv
# 2021-11-18 10:48:55.333891 --- ⬇️✅ downloaded file [LA FERME DU GRAND AIR] https://static.data.gouv.fr/resources/la-ferme-du-grand-air/20211110-143008/data.csv
# 2021-11-18 10:48:55.436681 --- ⬇️✅ downloaded file [Monfichier durand etasse complete pour daltoner cherbourg (6).csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-sas-durand-etasse/20210929-215258/data.csv
# 2021-11-18 10:48:55.547078 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-car2plug/20210812-174726/data.csv
# 2021-11-18 10:48:55.665633 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-car2plug/20210830-150208/data.csv
# 2021-11-18 10:48:55.779916 --- ⬇️✅ downloaded file [irve_accor_louvre_hotels.csv] https://static.data.gouv.fr/resources/bornes-de-recharge-pour-vehicules-electriques-accor-hotels-et-louvre-hotels-group/20210924-121114/data.csv
# 2021-11-18 10:48:55.869181 --- ⬇️✅ downloaded file [irve-accor-101121.csv] https://static.data.gouv.fr/resources/bornes-de-recharge-pour-vehicules-electriques-accor-hotels-et-louvre-hotels-group/20211110-185041/irve-accor-101121.csv
# 2021-11-18 10:48:55.980609 --- ⬇️✅ downloaded file [irve-sdem50-20210924.csv] https://static.data.gouv.fr/resources/e-charge50/20210926-123535/irve-sdem50-20210924.csv
# 2021-11-18 10:48:56.085662 --- ⬇️✅ downloaded file [STBM] https://static.data.gouv.fr/resources/stbm/20210908-103504/data.csv
# 2021-11-18 10:48:56.192828 --- ⬇️✅ downloaded file [BDS MENUISERIE] https://static.data.gouv.fr/resources/bds-menuiserie/20210902-142943/data.csv
# 2021-11-18 10:48:56.294864 --- ⬇️✅ downloaded file [LE DOMAINE DES CIGOGNES] https://static.data.gouv.fr/resources/le-domaine-des-cigognes/20210903-095840/data.csv
# 2021-11-18 10:48:56.395122 --- ⬇️✅ downloaded file [Bornes IRVE L2B] https://static.data.gouv.fr/resources/bornes-irve-l2b/20211004-140138/datagouv-irve-2021-10-04.csv
# 2021-11-18 10:48:56.497325 --- ⬇️✅ downloaded file [Monfichier.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-autorecharge/20210809-103558/data.csv
# 2021-11-18 10:48:56.630755 --- ⬇️✅ downloaded file [EGSM] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-egsm/20210805-100406/data.csv
# 2021-11-18 10:48:56.727584 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-eco-pi-sas/20210916-112602/data.csv
# 2021-11-18 10:48:56.828403 --- ⬇️✅ downloaded file [Monfichier.csv.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-organisation-spie-citynetworks/20210921-152744/data.csv
# 2021-11-18 10:48:56.970946 --- ⬇️✅ downloaded file [Monfichier] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-26/20210913-143141/data.csv
# 2021-11-18 10:48:57.093179 --- ⬇️✅ downloaded file [irve-wiiiz-20211006.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-irve/20211006-151405/irve-wiiiz-20211006.csv
# 2021-11-18 10:48:57.224656 --- ⬇️✅ downloaded file [irve-wiiizcasa-20211006.csv] https://static.data.gouv.fr/resources/infrastructures-de-recharge-pour-vehicules-electriques-irve/20211006-155413/irve-wiiizcasa-20211006.csv
# 2021-11-18 10:48:57.238563 - ℹ️ STARTING SCHEMA: etalab/schema-lieux-covoiturage
# 2021-11-18 10:48:57.239055 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.239105 - ℹ️ STARTING SCHEMA: etalab/schema-passage-a-niveau
# 2021-11-18 10:48:57.239385 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.239436 - ℹ️ STARTING SCHEMA: etalab/schema-sdirve
# 2021-11-18 10:48:57.239521 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.239548 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement
# 2021-11-18 10:48:57.239764 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.239815 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement-cyclable
# 2021-11-18 10:48:57.240043 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.240265 - ℹ️ STARTING SCHEMA: etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 10:48:57.240367 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.240446 - ℹ️ STARTING SCHEMA: openmaraude/schema-stationstaxi
# 2021-11-18 10:48:57.240680 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.240718 - ℹ️ STARTING SCHEMA: scdl/budget
# 2021-11-18 10:48:57.240945 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.241023 - ℹ️ STARTING SCHEMA: scdl/catalogue
# 2021-11-18 10:48:57.241130 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.241181 - ℹ️ STARTING SCHEMA: scdl/deliberations
# 2021-11-18 10:48:57.241394 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.241680 - ℹ️ STARTING SCHEMA: scdl/equipements
# 2021-11-18 10:48:57.241779 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.241814 - ℹ️ STARTING SCHEMA: scdl/menus-collectifs
# 2021-11-18 10:48:57.241914 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.241938 - ℹ️ STARTING SCHEMA: scdl/plats-menus-collectifs
# 2021-11-18 10:48:57.242190 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# 2021-11-18 10:48:57.242250 - ℹ️ STARTING SCHEMA: scdl/subventions
# 2021-11-18 10:48:57.242480 -- ❌ No reference table made for this schema (schema not to consolidate, no version to consolidate or no resource found).
# CPU times: user 4.34 s, sys: 538 ms, total: 4.87 s
# Wall time: 18.5 s

# %% [markdown]
# ## Consolidation

# %%
# %%time
for schema_name in config_dict.keys() :
    
    print('{} - ℹ️ STARTING SCHEMA: {}'.format(datetime.now(), schema_name))
    
    schema_data_path = Path(data_path) / schema_name.replace('/','_')
    
    if os.path.exists(schema_data_path) :
        
        schema_consolidated_data_path = Path(consolidated_data_path) / schema_name.replace('/','_')
        schema_consolidated_data_path.mkdir(exist_ok=True)
        
        ref_table_path = os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_')))
        df_ref = pd.read_csv(ref_table_path) #(This file necessarily exists if data folder exists)
        
        #We will test if downloaded files are empty or not (so we set default values)
        df_ref['is_empty'] = np.nan
        df_ref.loc[(df_ref['is_downloaded'] == True), 'is_empty'] = False
        
        schema_dict = get_schema_dict(schema_name, schemas_catalogue_list)
        
        version_names_list = [col.replace('is_valid_v_','') for col in df_ref.columns if col.startswith('is_valid_v_')]
        
        for version in schema_dict['versions'] :
            version_name = version['version_name']
            if version_name in version_names_list :
                df_ref_v = df_ref[(df_ref['is_valid_v_'+version_name] == True) & (df_ref['is_downloaded'] == True)]
                
                if len(df_ref_v) > 0 :
                    #Get schema version parameters for ddup
                    version_dict = requests.get(version['schema_url']).json()
                    version_cols_list = [field_dict['name'] for field_dict in version_dict['fields']]
                    
                    if 'primaryKey' in version_dict.keys() :
                        primary_key = version_dict['primaryKey']
                    else :
                        primary_key = None
                        
                    df_r_list = []
                    
                    for index,row in df_ref_v.iterrows():
                        file_path = os.path.join(schema_data_path, row['dataset_slug'], '{}.csv'.format(row['resource_id']))
                        with open(file_path,'rb') as f:
                            encoding = chardet.detect(f.read()).get('encoding')
                            if(encoding == 'Windows-1254'):
                                encoding = 'iso-8859-1'
                        
                        df_r = pd.read_csv(file_path, sep=None, engine="python", dtype='str', encoding=encoding, na_filter=False)
                        
                        if len(df_r) > 0 : #Keeping only non empty files
                            #Keep only schema columns (and add empty columns for missing ones)
                            df_r = df_r[[col for col in version_cols_list if col in df_r.columns]]
                            for col in version_cols_list :
                                if col not in df_r.columns :
                                    df_r[col] = np.nan

                            df_r['last_modified'] = row['resource_last_modified']
                            df_r['datagouv_dataset_id'] = row['dataset_id']
                            df_r['datagouv_resource_id'] = row['resource_id']
                            df_r['datagouv_organization_or_owner'] = row['organization_or_owner']
                            df_r_list += [df_r]
                            
                        else :
                            df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'is_empty'] = True
                    
                    if len(df_r_list) >= 5 :
                        df_conso = pd.concat(df_r_list, ignore_index=True)

                        #Sorting by most recent (resource last modification date at the moment)
                        df_conso = df_conso.sort_values('last_modified', ascending=False)

                        #Deduplication
                        if primary_key is not None :
                            ddup_cols = primary_key
                        else :
                            ddup_cols = version_cols_list

                        df_conso = df_conso.drop_duplicates(ddup_cols, keep='first').reset_index(drop=True)  
                        
                        #Avoid "null" value in CSV files
                        df_conso = df_conso.fillna('')
                        
                        df_conso.to_csv(os.path.join(schema_consolidated_data_path, 'consolidation_{}_v_{}_{}.csv'.format(schema_name.replace('/','_'), version_name, consolidation_date_str)), index=False, encoding="utf-8",na_rep='null')
                        print('{} -- ✅ DONE: {} version {}'.format(datetime.today(), schema_name, version_name))
                    
                    else :
                        print('{} -- ⚠️ Less than 5 (non-empty) valid resources for version {} : consolidation file is not built'.format(datetime.today(), version_name))
                    
                else :
                    print('{} -- ⚠️ No valid resource for version {} of this schema'.format(datetime.today(), version_name))
        
        df_ref.to_csv(ref_table_path, index=False)
    
    else :
        print('{} -- ❌ No data downloaded for this schema.'.format(datetime.today()))
# Out:
# 2021-11-18 10:49:11.113054 - ℹ️ STARTING SCHEMA: Archivistes75/registre_entrees
# 2021-11-18 10:49:11.113740 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.113791 - ℹ️ STARTING SCHEMA: CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 10:49:11.114005 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.114054 - ℹ️ STARTING SCHEMA: MTES-MCT/acceslibre-schema
# 2021-11-18 10:49:11.114203 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.114237 - ℹ️ STARTING SCHEMA: NaturalSolutions/schema-arbre
# 2021-11-18 10:49:11.114443 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.114726 - ℹ️ STARTING SCHEMA: arsante/schema-dae
# 2021-11-18 10:49:11.115350 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.115402 - ℹ️ STARTING SCHEMA: datakode/schema-pei
# 2021-11-18 10:49:11.115741 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.115807 - ℹ️ STARTING SCHEMA: etalab/schema-decp-dpa
# 2021-11-18 10:49:11.116444 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.116523 - ℹ️ STARTING SCHEMA: etalab/schema-hautes-remunerations
# 2021-11-18 10:49:11.116633 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.116659 - ℹ️ STARTING SCHEMA: etalab/schema-inclusion-numerique
# 2021-11-18 10:49:11.116723 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:11.116744 - ℹ️ STARTING SCHEMA: etalab/schema-irve
# 2021-11-18 10:49:19.933631 -- ✅ DONE: etalab/schema-irve version 2.0.2
# 2021-11-18 10:49:19.942403 - ℹ️ STARTING SCHEMA: etalab/schema-lieux-covoiturage
# 2021-11-18 10:49:19.942885 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.942939 - ℹ️ STARTING SCHEMA: etalab/schema-passage-a-niveau
# 2021-11-18 10:49:19.943077 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.943098 - ℹ️ STARTING SCHEMA: etalab/schema-sdirve
# 2021-11-18 10:49:19.943281 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.943337 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement
# 2021-11-18 10:49:19.943759 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.944033 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement-cyclable
# 2021-11-18 10:49:19.944107 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.944174 - ℹ️ STARTING SCHEMA: etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 10:49:19.944251 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.944283 - ℹ️ STARTING SCHEMA: openmaraude/schema-stationstaxi
# 2021-11-18 10:49:19.944609 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.944659 - ℹ️ STARTING SCHEMA: scdl/budget
# 2021-11-18 10:49:19.944757 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.944798 - ℹ️ STARTING SCHEMA: scdl/catalogue
# 2021-11-18 10:49:19.945037 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.945065 - ℹ️ STARTING SCHEMA: scdl/deliberations
# 2021-11-18 10:49:19.945128 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.945342 - ℹ️ STARTING SCHEMA: scdl/equipements
# 2021-11-18 10:49:19.945510 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.945539 - ℹ️ STARTING SCHEMA: scdl/menus-collectifs
# 2021-11-18 10:49:19.945695 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.945719 - ℹ️ STARTING SCHEMA: scdl/plats-menus-collectifs
# 2021-11-18 10:49:19.945831 -- ❌ No data downloaded for this schema.
# 2021-11-18 10:49:19.945853 - ℹ️ STARTING SCHEMA: scdl/subventions
# 2021-11-18 10:49:19.945958 -- ❌ No data downloaded for this schema.
# CPU times: user 8.61 s, sys: 114 ms, total: 8.72 s
# Wall time: 8.83 s

# %% [markdown]
# ## Upload

# %%
# %%time
for schema_name in config_dict.keys() :
    
    with open(config_path, 'r') as f :
        config_dict = yaml.safe_load(f)
    
    print('{} - ℹ️ STARTING SCHEMA: {}'.format(datetime.now(), schema_name))
    
    schema_consolidated_data_path = Path(consolidated_data_path) / schema_name.replace('/','_')
    
    if os.path.exists(schema_consolidated_data_path) :
        #Check if dataset_id is in config. If not, create a dataset on datagouv
        schema_config = config_dict[schema_name]
        if(('publication' in schema_config.keys()) and schema_config['publication'] == True): 
            if 'consolidated_dataset_id' not in schema_config.keys() :
                response = create_schema_consolidation_dataset(schema_name, schemas_catalogue_list, api_url)
                if response.status_code == 201 :
                    consolidated_dataset_id = response.json()['id']
                    update_config_file(schema_name, 'consolidated_dataset_id', consolidated_dataset_id, config_path)
                    print('{} -- 🟢 No consolidation dataset for this schema - Successfully created (id: {})'.format(datetime.today(), consolidated_dataset_id))
                else :
                    print('{} -- 🔴 No consolidation dataset for this schema - Failed to create one'.format(datetime.today()))
            else :
                consolidated_dataset_id = schema_config['consolidated_dataset_id']
                
            schemas_report_dict[schema_name]['consolidated_dataset_id'] = consolidated_dataset_id
                
            #Creating last consolidation resources
            version_names_list = [filename.replace('consolidation_'+schema_name.replace('/','_')+'_v_', '').replace('_'+ consolidation_date_str +'.csv','') for filename in os.listdir(schema_consolidated_data_path) if not filename.startswith('.')]
            
            for version_name in sorted(version_names_list) :
                with open(config_path, 'r') as f :
                    config_dict = yaml.safe_load(f)
            
                schema = {
                    "name": schema_name,
                    "version": version_name
                }
                obj = {}
                obj['schema'] = schema
                obj['type'] = 'main'
                obj['title'] = "Dernière version consolidée (v{} du schéma) - {}".format(version_name, consolidation_date_str)
                obj['format'] = 'csv'
                
                file_path = os.path.join(schema_consolidated_data_path, 'consolidation_{}_v_{}_{}.csv'.format(schema_name.replace('/','_'), version_name, consolidation_date_str))
                
                
                #Uploading file (creating a new resource if version was not there before)
                try :
                    r_id = config_dict[schema_name]['latest_resource_ids'][version_name]
                    url = api_url + 'datasets/' + consolidated_dataset_id + '/resources/' + r_id + '/upload/'
                    r_to_create = False
                    expected_status_code = 200
                    
                except KeyError :
                    url = api_url + 'datasets/' + consolidated_dataset_id + '/upload/'
                    r_to_create = True
                    expected_status_code = 201
                
                with open(file_path, 'rb') as file:
                    files = {'file': (file_path.split('/')[-1], file.read())}
                
                response = requests.post(url, files=files, headers=HEADERS)

                if response.status_code == expected_status_code :
                    if r_to_create == True :
                        r_id = response.json()['id']
                        update_config_version_resource_id(schema_name, version_name, r_id, config_path)
                        print('{} --- ➕ New latest resource ID created for {} v{} (id: {})'.format(datetime.today(), schema_name, version_name, r_id))
                else :
                    r_id = None
                    print('{} --- ⚠️ Version {}: file could not be uploaded.'.format(datetime.today(), version_name))
                    
                    
                if r_id is not None :
                    r_url = api_url + 'datasets/{}/resources/{}/'.format(consolidated_dataset_id, r_id)
                    r_response = requests.put(r_url, json=obj, headers=HEADERS)

                    if r_response.status_code == 200 :
                        if r_to_create == True :
                            print('{} --- ✅ Version {}: Successfully created consolidated file.'.format(datetime.today(), version_name))
                        else :
                            print('{} --- ✅ Version {}: Successfully updated consolidated file.'.format(datetime.today(), version_name))
                    else :
                        print('{} --- ⚠️ Version {}: file uploaded but metadata could not be updated.'.format(datetime.today(), version_name))
        else:
            schemas_report_dict[schema_name]['consolidated_dataset_id'] = np.nan
            print('{} -- ❌ No publication for this schema.'.format(datetime.today()))

    else :
        schemas_report_dict[schema_name]['consolidated_dataset_id'] = np.nan
        print('{} -- ❌ No consolidated file for this schema.'.format(datetime.today()))

#Reopening config file to update config_dict (in case it has to be reused right after)
with open(config_path, 'r') as f :
    config_dict = yaml.safe_load(f)
# Out:
# 2021-11-18 10:51:13.341202 - ℹ️ STARTING SCHEMA: Archivistes75/registre_entrees
# 2021-11-18 10:51:13.341528 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.360227 - ℹ️ STARTING SCHEMA: CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 10:51:13.360936 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.378374 - ℹ️ STARTING SCHEMA: MTES-MCT/acceslibre-schema
# 2021-11-18 10:51:13.378975 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.391832 - ℹ️ STARTING SCHEMA: NaturalSolutions/schema-arbre
# 2021-11-18 10:51:13.392339 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.405082 - ℹ️ STARTING SCHEMA: arsante/schema-dae
# 2021-11-18 10:51:13.405651 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.417355 - ℹ️ STARTING SCHEMA: datakode/schema-pei
# 2021-11-18 10:51:13.417593 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.430647 - ℹ️ STARTING SCHEMA: etalab/schema-decp-dpa
# 2021-11-18 10:51:13.431330 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.443194 - ℹ️ STARTING SCHEMA: etalab/schema-hautes-remunerations
# 2021-11-18 10:51:13.443657 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.454951 - ℹ️ STARTING SCHEMA: etalab/schema-inclusion-numerique
# 2021-11-18 10:51:13.455360 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:13.467186 - ℹ️ STARTING SCHEMA: etalab/schema-irve
# 2021-11-18 10:51:14.735294 --- ✅ Version 2.0.2: Successfully updated consolidated file.
# 2021-11-18 10:51:14.758912 - ℹ️ STARTING SCHEMA: etalab/schema-lieux-covoiturage
# 2021-11-18 10:51:14.759589 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.774280 - ℹ️ STARTING SCHEMA: etalab/schema-passage-a-niveau
# 2021-11-18 10:51:14.774867 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.786236 - ℹ️ STARTING SCHEMA: etalab/schema-sdirve
# 2021-11-18 10:51:14.786824 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.797911 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement
# 2021-11-18 10:51:14.798592 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.809820 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement-cyclable
# 2021-11-18 10:51:14.810610 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.821869 - ℹ️ STARTING SCHEMA: etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 10:51:14.822316 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.833326 - ℹ️ STARTING SCHEMA: openmaraude/schema-stationstaxi
# 2021-11-18 10:51:14.834010 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.844846 - ℹ️ STARTING SCHEMA: scdl/budget
# 2021-11-18 10:51:14.845342 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.856359 - ℹ️ STARTING SCHEMA: scdl/catalogue
# 2021-11-18 10:51:14.857000 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.868390 - ℹ️ STARTING SCHEMA: scdl/deliberations
# 2021-11-18 10:51:14.868822 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.880165 - ℹ️ STARTING SCHEMA: scdl/equipements
# 2021-11-18 10:51:14.880854 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.892170 - ℹ️ STARTING SCHEMA: scdl/menus-collectifs
# 2021-11-18 10:51:14.892829 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.903870 - ℹ️ STARTING SCHEMA: scdl/plats-menus-collectifs
# 2021-11-18 10:51:14.904432 -- ❌ No consolidated file for this schema.
# 2021-11-18 10:51:14.916381 - ℹ️ STARTING SCHEMA: scdl/subventions
# 2021-11-18 10:51:14.916895 -- ❌ No consolidated file for this schema.
# CPU times: user 366 ms, sys: 27.4 ms, total: 394 ms
# Wall time: 1.6 s

# %% [markdown]
# ## Schemas (versions) feedback loop on resources

# %% [markdown]
# ### Adding needed infos for each resource in reference tables

# %%
# %%time
for schema_name in config_dict.keys() :
    
    ref_table_path = os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_')))
    
    if os.path.isfile(ref_table_path) :
        df_ref = pd.read_csv(ref_table_path)

        df_ref = add_most_recent_valid_version(df_ref)
        df_ref['is_schema_version_to_update'] = df_ref.apply(is_schema_version_to_update, axis=1)
        df_ref['is_schema_to_add'] = df_ref.apply(is_schema_to_add, axis=1)
        df_ref['is_schema_to_drop'] = df_ref.apply(is_schema_to_drop, axis=1)
        
        df_ref.to_csv(ref_table_path, index=False)

        print('{} - ✅ Infos added for schema {}'.format(datetime.today(), schema_name))
        
    else :
        print('{} - ❌ No reference table for schema {}'.format(datetime.today(), schema_name))
# Out:
# 2021-11-18 10:59:35.430267 - ❌ No reference table for schema Archivistes75/registre_entrees
# 2021-11-18 10:59:35.431273 - ❌ No reference table for schema CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 10:59:35.431556 - ❌ No reference table for schema MTES-MCT/acceslibre-schema
# 2021-11-18 10:59:35.432003 - ❌ No reference table for schema NaturalSolutions/schema-arbre
# 2021-11-18 10:59:35.432522 - ❌ No reference table for schema arsante/schema-dae
# 2021-11-18 10:59:35.432673 - ❌ No reference table for schema datakode/schema-pei
# 2021-11-18 10:59:35.432910 - ❌ No reference table for schema etalab/schema-decp-dpa
# 2021-11-18 10:59:35.433876 - ❌ No reference table for schema etalab/schema-hautes-remunerations
# 2021-11-18 10:59:35.434217 - ❌ No reference table for schema etalab/schema-inclusion-numerique
# 2021-11-18 10:59:35.481881 - ✅ Infos added for schema etalab/schema-irve
# 2021-11-18 10:59:35.482408 - ❌ No reference table for schema etalab/schema-lieux-covoiturage
# 2021-11-18 10:59:35.482796 - ❌ No reference table for schema etalab/schema-passage-a-niveau
# 2021-11-18 10:59:35.483009 - ❌ No reference table for schema etalab/schema-sdirve
# 2021-11-18 10:59:35.483197 - ❌ No reference table for schema etalab/schema-stationnement
# 2021-11-18 10:59:35.483600 - ❌ No reference table for schema etalab/schema-stationnement-cyclable
# 2021-11-18 10:59:35.483814 - ❌ No reference table for schema etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 10:59:35.483885 - ❌ No reference table for schema openmaraude/schema-stationstaxi
# 2021-11-18 10:59:35.484031 - ❌ No reference table for schema scdl/budget
# 2021-11-18 10:59:35.484200 - ❌ No reference table for schema scdl/catalogue
# 2021-11-18 10:59:35.484477 - ❌ No reference table for schema scdl/deliberations
# 2021-11-18 10:59:35.484640 - ❌ No reference table for schema scdl/equipements
# 2021-11-18 10:59:35.484967 - ❌ No reference table for schema scdl/menus-collectifs
# 2021-11-18 10:59:35.485021 - ❌ No reference table for schema scdl/plats-menus-collectifs
# 2021-11-18 10:59:35.485166 - ❌ No reference table for schema scdl/subventions
# CPU times: user 49.9 ms, sys: 8.42 ms, total: 58.3 ms
# Wall time: 55 ms

# %% [markdown]
# ### Updating resources schemas and sending comments/mails to notify producers

# %% [markdown]
# ⚠️⚠️⚠️ **TODO: UNCOMMENT MAIL SENDING AND DISCUSSION COMMENTING (+ DELETE PRINTS) FOR NOTIFICATION TO PRODUCERS.**

# %%
# %%time
for schema_name in config_dict.keys() :
    
    ref_table_path = os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_')))
    
    if os.path.isfile(ref_table_path) :
        df_ref = pd.read_csv(ref_table_path)
        df_ref['resource_schema_update_success'] = np.nan
        df_ref['producer_notification_success'] = np.nan

        for idx, row in df_ref.iterrows() :
            if row['is_schema_version_to_update'] :
                resource_update_success = update_resource_schema(api_url, row['dataset_id'], row['resource_id'], schema_name, row['most_recent_valid_version'])
                df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'resource_schema_update_success'] = resource_update_success
                
                if resource_update_success == True :
                    title = 'Mise à jour de la version de la métadonnée schéma'
                    comment = updated_schema_comment_template.format(resource_title = row['resource_title'],
                                                                     schema_name = schema_name,
                                                                     initial_version_name = row['initial_version_name'],
                                                                     most_recent_valid_version = row['most_recent_valid_version']
                                                                    )
                    #comment_post = post_comment_on_dataset(dataset_id=row['dataset_id'],
                    #                                       title=title,
                    #                                       comment=comment,
                    #                                       api_url=api_url
                    #                                      )
                    #
                    #producer_notification_success = (comment_post.status_code == 201)
                    
                    #df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'producer_notification_success'] = producer_notification_success
                    #No notification at the moment:
                    df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'producer_notification_success'] = False
                    
            
            elif row['is_schema_to_add'] :
                resource_update_success = add_resource_schema(api_url, row['dataset_id'], row['resource_id'], schema_name, row['most_recent_valid_version'])
                df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'resource_schema_update_success'] = resource_update_success
                
                if resource_update_success == True :
                    title = 'Ajout de la métadonnée schéma'
                    comment = added_schema_comment_template.format(resource_title = row['resource_title'],
                                                             schema_name = schema_name,
                                                             most_recent_valid_version = row['most_recent_valid_version']
                                                            )
                    #comment_post = post_comment_on_dataset(dataset_id=row['dataset_id'],
                    #                                       title=title,
                    #                                       comment=comment,
                    #                                       api_url=api_url
                    #                                      )
                    #
                    #producer_notification_success = (comment_post.status_code == 201)
                    #df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'producer_notification_success'] = producer_notification_success
                    #No notification at the moment:
                    df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'producer_notification_success'] = False
            
            #Right now, we don't drop schema and do no notification
            elif row['is_schema_to_drop'] :
            #    resource_update_success = delete_resource_schema(api_url, row['dataset_id'], row['resource_id'], schema_name)
            #    df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'resource_schema_update_success'] = resource_update_success
            #    
            #    if resource_update_success == True :
            #        title = 'Suppression de la métadonnée schéma'
            #        
            #        mails_type, mails_list = get_owner_or_admin_mails(row['dataset_id'], api_url)
            #        
            #        if len(mails_list) > 0 : #If we found some email addresses, we send mails
            #            
            #            if mails_type == 'organisation_admins' :
            #                message = deleted_schema_mail_template_org.format(organisation_name=row['organization_or_owner'],
            #                                                                  dataset_title=row['dataset_title'],
            #                                                                  resource_title=row['resource_title'],
            #                                                                  schema_name=schema_name,
            #                                                                  schema_url=get_schema_dict(schema_name, schemas_catalogue_list)['schema_url'],
            #                                                                  resource_url=row['resource_url']
            #                                                                 )
            #            elif mails_type == 'owner' :
            #                message = deleted_schema_mail_template_own.format(dataset_title=row['dataset_title'],
            #                                                                  resource_title=row['resource_title'],
            #                                                                  schema_name=schema_name,
            #                                                                  schema_url=get_schema_dict(schema_name, schemas_catalogue_list)['schema_url'],
            #                                                                  resource_url=row['resource_url']
            #                                                                 )
            #                
            #            
            #            #Sending mail
            #            
            #            producer_notification_success_list = []
            #            print('- {} | {}:'.format(row['dataset_title'], row['resource_title']))
            #            for mail_to in mails_list :
            #                #mail_send = send_email(subject=title,
            #                #                       message=message,
            #                #                       mail_from=mail_from,
            #                #                       mail_to=mail_to,
            #                #                       smtp_host=smtp_host,
            #                #                       smtp_user=smtp_user,
            #                #                       smtp_password=smtp_password)

            #                #producer_notification_success_list += [(mail_send.status_code == 250)]
            #            
            #            #producer_notification_success = any(producer_notification_success_list) # Success if at least one person receives the mail
            #            
            #        else : #If no mail address, we post a comment on dataset
            #            comment = deleted_schema_comment_template.format(resource_title=row['resource_title'],
            #                                                             schema_name=schema_name,
            #                                                             schema_url=get_schema_dict(schema_name, schemas_catalogue_list)['schema_url'],
            #                                                             resource_url=row['resource_url']
            #                                                            )
            #            
            #            #comment_post = post_comment_on_dataset(dataset_id=row['dataset_id'],
            #            #                                       title=title,
            #            #                                       comment=comment,
            #            #                                       api_url=api_url
            #            #                                      )
            #        
            #            #producer_notification_success = (comment_post.status_code == 201)
            #        
            #        #df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'producer_notification_success'] = producer_notification_success
            
                #TO DROP when schema will be deleted and producer notified:
                df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'resource_schema_update_success'] = False
                df_ref.loc[(df_ref['resource_id'] == row['resource_id']), 'producer_notification_success'] = False
            
        
        df_ref.to_csv(ref_table_path, index=False)

        print('{} - ✅ Resources updated for schema {}'.format(datetime.today(), schema_name))
        
    else :
        print('{} - ❌ No reference table for schema {}'.format(datetime.today(), schema_name))
# Out:
# 2021-11-18 11:06:37.846343 - ❌ No reference table for schema Archivistes75/registre_entrees
# 2021-11-18 11:06:37.846735 - ❌ No reference table for schema CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 11:06:37.846972 - ❌ No reference table for schema MTES-MCT/acceslibre-schema
# 2021-11-18 11:06:37.847061 - ❌ No reference table for schema NaturalSolutions/schema-arbre
# 2021-11-18 11:06:37.847147 - ❌ No reference table for schema arsante/schema-dae
# 2021-11-18 11:06:37.847376 - ❌ No reference table for schema datakode/schema-pei
# 2021-11-18 11:06:37.847522 - ❌ No reference table for schema etalab/schema-decp-dpa
# 2021-11-18 11:06:37.847579 - ❌ No reference table for schema etalab/schema-hautes-remunerations
# 2021-11-18 11:06:37.847624 - ❌ No reference table for schema etalab/schema-inclusion-numerique
# 2021-11-18 11:06:38.086174 - ✅ Resources updated for schema etalab/schema-irve
# 2021-11-18 11:06:38.086699 - ❌ No reference table for schema etalab/schema-lieux-covoiturage
# 2021-11-18 11:06:38.086862 - ❌ No reference table for schema etalab/schema-passage-a-niveau
# 2021-11-18 11:06:38.086968 - ❌ No reference table for schema etalab/schema-sdirve
# 2021-11-18 11:06:38.087138 - ❌ No reference table for schema etalab/schema-stationnement
# 2021-11-18 11:06:38.087245 - ❌ No reference table for schema etalab/schema-stationnement-cyclable
# 2021-11-18 11:06:38.087564 - ❌ No reference table for schema etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 11:06:38.087989 - ❌ No reference table for schema openmaraude/schema-stationstaxi
# 2021-11-18 11:06:38.088194 - ❌ No reference table for schema scdl/budget
# 2021-11-18 11:06:38.088441 - ❌ No reference table for schema scdl/catalogue
# 2021-11-18 11:06:38.088616 - ❌ No reference table for schema scdl/deliberations
# 2021-11-18 11:06:38.088654 - ❌ No reference table for schema scdl/equipements
# 2021-11-18 11:06:38.088681 - ❌ No reference table for schema scdl/menus-collectifs
# 2021-11-18 11:06:38.088856 - ❌ No reference table for schema scdl/plats-menus-collectifs
# 2021-11-18 11:06:38.089324 - ❌ No reference table for schema scdl/subventions
# CPU times: user 239 ms, sys: 13.6 ms, total: 253 ms
# Wall time: 243 ms

# %% [markdown]
# ## Updating consolidation documentation resource

# %%
# %%time
for schema_name in config_dict.keys() :
    
    ref_table_path = os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_')))
    
    with open(config_path, 'r') as f :
        config_dict = yaml.safe_load(f)
    
    print('{} - ℹ️ STARTING SCHEMA: {}'.format(datetime.now(), schema_name))
    
    schema_config = config_dict[schema_name]
    if(('publication' in schema_config.keys()) and schema_config['publication'] == True): 
        if os.path.isfile(ref_table_path) :
        
            if 'consolidated_dataset_id' in schema_config.keys() :
                consolidated_dataset_id = schema_config['consolidated_dataset_id']
                
                obj = {}
                obj['type'] = 'documentation'
                obj['title'] = "Documentation sur la consolidation - {}".format(consolidation_date_str)

                #Uploading documentation file (creating a new resource if version was not there before)
                try :
                    doc_r_id = config_dict[schema_name]['documentation_resource_id']
                    url = api_url + 'datasets/' + consolidated_dataset_id + '/resources/' + doc_r_id + '/upload/'
                    doc_r_to_create = False
                    expected_status_code = 200

                except KeyError :
                    url = api_url + 'datasets/' + consolidated_dataset_id + '/upload/'
                    doc_r_to_create = True
                    expected_status_code = 201

                with open(ref_table_path, 'rb') as file:
                    files = {'file': (ref_table_path.split('/')[-1], file.read())}

                response = requests.post(url, files=files, headers=HEADERS)
                
                if response.status_code == expected_status_code :
                    if doc_r_to_create == True :
                        doc_r_id = response.json()['id']
                        update_config_file(schema_name, 'documentation_resource_id', doc_r_id, config_path)
                        print('{} --- ➕ New documentation resource ID created for {} (id: {})'.format(datetime.today(), schema_name, doc_r_id))
                else :
                    doc_r_id = None
                    print('{} --- ⚠️ Documentation file could not be uploaded.'.format(datetime.today()))


                if doc_r_id is not None :
                    doc_r_url = api_url + 'datasets/{}/resources/{}/'.format(consolidated_dataset_id, doc_r_id)
                    doc_r_response = requests.put(doc_r_url, json=obj, headers=HEADERS)
                    if doc_r_response.status_code == 200 :
                        if doc_r_to_create == True :
                            print('{} --- ✅ Successfully created documentation file.'.format(datetime.today()))
                        else :
                            print('{} --- ✅ Successfully updated documentation file.'.format(datetime.today()))
                    else :
                        print('{} --- ⚠️ Documentation file uploaded but metadata could not be updated.'.format(datetime.today()))
            
            else :
                print('{} -- ❌ No consolidation dataset ID for this schema.'.format(datetime.today()))
                
        else :
            print('{} -- ❌ No reference table for this schema.'.format(datetime.today()))
    
    else :
        print('{} -- ❌ No publication for this schema.'.format(datetime.today()))

#Reopening config file to update config_dict (in case it has to be reused right after)
with open(config_path, 'r') as f :
    config_dict = yaml.safe_load(f)
# Out:
# 2021-11-18 11:06:55.497233 - ℹ️ STARTING SCHEMA: Archivistes75/registre_entrees
# 2021-11-18 11:06:55.497612 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.516525 - ℹ️ STARTING SCHEMA: CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 11:06:55.517004 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.531991 - ℹ️ STARTING SCHEMA: MTES-MCT/acceslibre-schema
# 2021-11-18 11:06:55.532308 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.544021 - ℹ️ STARTING SCHEMA: NaturalSolutions/schema-arbre
# 2021-11-18 11:06:55.544664 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.556152 - ℹ️ STARTING SCHEMA: arsante/schema-dae
# 2021-11-18 11:06:55.556600 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.567085 - ℹ️ STARTING SCHEMA: datakode/schema-pei
# 2021-11-18 11:06:55.567446 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.578085 - ℹ️ STARTING SCHEMA: etalab/schema-decp-dpa
# 2021-11-18 11:06:55.578584 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.588947 - ℹ️ STARTING SCHEMA: etalab/schema-hautes-remunerations
# 2021-11-18 11:06:55.589262 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.600346 - ℹ️ STARTING SCHEMA: etalab/schema-inclusion-numerique
# 2021-11-18 11:06:55.600939 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:55.611574 - ℹ️ STARTING SCHEMA: etalab/schema-irve
# 2021-11-18 11:06:56.257042 --- ✅ Successfully updated documentation file.
# 2021-11-18 11:06:56.284237 - ℹ️ STARTING SCHEMA: etalab/schema-lieux-covoiturage
# 2021-11-18 11:06:56.284743 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.300807 - ℹ️ STARTING SCHEMA: etalab/schema-passage-a-niveau
# 2021-11-18 11:06:56.301198 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.317615 - ℹ️ STARTING SCHEMA: etalab/schema-sdirve
# 2021-11-18 11:06:56.317812 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.331123 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement
# 2021-11-18 11:06:56.331544 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.341822 - ℹ️ STARTING SCHEMA: etalab/schema-stationnement-cyclable
# 2021-11-18 11:06:56.342144 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.352841 - ℹ️ STARTING SCHEMA: etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 11:06:56.353350 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.363598 - ℹ️ STARTING SCHEMA: openmaraude/schema-stationstaxi
# 2021-11-18 11:06:56.363980 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.375041 - ℹ️ STARTING SCHEMA: scdl/budget
# 2021-11-18 11:06:56.375630 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.385620 - ℹ️ STARTING SCHEMA: scdl/catalogue
# 2021-11-18 11:06:56.386200 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.396370 - ℹ️ STARTING SCHEMA: scdl/deliberations
# 2021-11-18 11:06:56.396752 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.407260 - ℹ️ STARTING SCHEMA: scdl/equipements
# 2021-11-18 11:06:56.407803 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.418205 - ℹ️ STARTING SCHEMA: scdl/menus-collectifs
# 2021-11-18 11:06:56.418679 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.428427 - ℹ️ STARTING SCHEMA: scdl/plats-menus-collectifs
# 2021-11-18 11:06:56.429062 -- ❌ No reference table for this schema.
# 2021-11-18 11:06:56.439122 - ℹ️ STARTING SCHEMA: scdl/subventions
# 2021-11-18 11:06:56.439635 -- ❌ No reference table for this schema.
# CPU times: user 360 ms, sys: 20.7 ms, total: 381 ms
# Wall time: 971 ms

# %% [markdown]
# ## Consolidation Reports

# %% [markdown]
# ### Report by schema

# %%
reports_list = []

for schema_name in schemas_report_dict.keys() :
    schema_report_dict = schemas_report_dict[schema_name]
    schema_report_dict['schema_name'] = schema_name
    reports_list += [schema_report_dict]
    
reports_df = pd.DataFrame(reports_list)

reports_df = reports_df[['schema_name'] + [col for col in reports_df.columns if col != 'schema_name']].rename(columns={'config_created':'new_config_created'}) #rename to drop at next launch

# %%
stats_df_list = []
for schema_name in config_dict.keys() :
    
    ref_table_path = os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_')))
    
    if os.path.isfile(ref_table_path) :
        df_ref = pd.read_csv(ref_table_path)
        df_ref['schema_name'] = schema_name
        df_ref['is_schema_version_updated'] = df_ref['is_schema_version_to_update'] & df_ref['resource_schema_update_success']
        df_ref['is_schema_added'] = df_ref['is_schema_to_add'] & df_ref['resource_schema_update_success']
        df_ref['is_schema_dropped'] = df_ref['is_schema_to_drop'] & df_ref['resource_schema_update_success']
        df_ref['resource_schema_update_success'] = False
        df_ref.to_csv(ref_table_path, index=False)
        stats_df_list += [df_ref[['schema_name', 'is_schema_version_to_update', 'is_schema_to_add', 'is_schema_to_drop', 'resource_schema_update_success', 'is_schema_version_updated','is_schema_added', 'is_schema_dropped']].fillna(False).groupby('schema_name').sum().reset_index()]

stats_df = pd.concat(stats_df_list).reset_index(drop=True)

# %%
stats_df.head()
# Out:
#           schema_name  is_schema_version_to_update  is_schema_to_add  \
# 0  etalab/schema-irve                            0                 0
#
#    is_schema_to_drop  resource_schema_update_success  \
# 0                288                               0
#
#    is_schema_version_updated  is_schema_added  is_schema_dropped
# 0                          0                0                  0

# %%
reports_df = reports_df.merge(stats_df, on='schema_name', how='left')

# %%
reports_df.head()
# Out:
#               schema_name  nb_versions  new_config_created  \
# 0      etalab/schema-irve            7               False
# 1  etalab/schema-decp-dpa            1               False
# 2          scdl/catalogue            2               False
# 3      scdl/deliberations            6               False
# 4        scdl/equipements            2               False
#
#    nb_versions_to_drop_in_config  nb_resources_found_by_schema  \
# 0                            6.0                         462.0
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    nb_resources_found_by_tags  nb_resources_found_by_search_words  \
# 0                         0.0                               280.0
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
#
#    nb_valid_resources   consolidated_dataset_id  is_schema_version_to_update  \
# 0               168.0  5448d3e0c751df01f85d0572                          0.0
# 1                 NaN                       NaN                          NaN
# 2                 NaN                       NaN                          NaN
# 3                 NaN                       NaN                          NaN
# 4                 NaN                       NaN                          NaN
#
#    is_schema_to_add  is_schema_to_drop  resource_schema_update_success  \
# 0               0.0              288.0                             0.0
# 1               NaN                NaN                             NaN
# 2               NaN                NaN                             NaN
# 3               NaN                NaN                             NaN
# 4               NaN                NaN                             NaN
#
#    is_schema_version_updated  is_schema_added  is_schema_dropped
# 0                        0.0              0.0                0.0
# 1                        NaN              NaN                NaN
# 2                        NaN              NaN                NaN
# 3                        NaN              NaN                NaN
# 4                        NaN              NaN                NaN

# %%
reports_df.to_excel(os.path.join(report_tables_path, 'report_by_schema_{}.xlsx'.format(consolidation_date_str)), index=False)
reports_df.to_csv(os.path.join(report_tables_path, 'report_by_schema_{}.csv'.format(consolidation_date_str)), index=False)

# %% [markdown]
# ## Detailed reports (by schema and resource source)

# %%
# %%time
for schema_name in config_dict.keys() :
    
    ref_table_path = os.path.join(ref_tables_path, 'ref_table_{}.csv'.format(schema_name.replace('/', '_')))
    
    if os.path.isfile(ref_table_path) :
        df_ref = pd.read_csv(ref_table_path)        
    
        df_ref['total_nb_resources'] = 1
        df_ref['error_type'].fillna('no-error', inplace=True)

        cols_to_sum = ['total_nb_resources']
        cols_to_sum += [col for col in df_ref.columns if col.startswith('is_')]
        df_report = df_ref.groupby(['resource_found_by', 'error_type']).agg({col:sum for col in cols_to_sum}).reset_index()

        df_report.to_excel(os.path.join(report_tables_path, 'report_table_{}.xlsx'.format(schema_name.replace('/', '_'))), index=False)

        print('{} - ✅ Report done for schema {}'.format(datetime.today(), schema_name))
        
    else :
        print('{} - ❌ No reference table for schema {}'.format(datetime.today(), schema_name))
# Out:
# 2021-11-18 11:20:06.559960 - ❌ No reference table for schema Archivistes75/registre_entrees
# 2021-11-18 11:20:06.560575 - ❌ No reference table for schema CEREMA/schema-arrete-circulation-marchandises
# 2021-11-18 11:20:06.560734 - ❌ No reference table for schema MTES-MCT/acceslibre-schema
# 2021-11-18 11:20:06.561075 - ❌ No reference table for schema NaturalSolutions/schema-arbre
# 2021-11-18 11:20:06.561450 - ❌ No reference table for schema arsante/schema-dae
# 2021-11-18 11:20:06.561679 - ❌ No reference table for schema datakode/schema-pei
# 2021-11-18 11:20:06.561971 - ❌ No reference table for schema etalab/schema-decp-dpa
# 2021-11-18 11:20:06.562404 - ❌ No reference table for schema etalab/schema-hautes-remunerations
# 2021-11-18 11:20:06.562754 - ❌ No reference table for schema etalab/schema-inclusion-numerique
# 2021-11-18 11:20:06.597567 - ✅ Report done for schema etalab/schema-irve
# 2021-11-18 11:20:06.598124 - ❌ No reference table for schema etalab/schema-lieux-covoiturage
# 2021-11-18 11:20:06.598445 - ❌ No reference table for schema etalab/schema-passage-a-niveau
# 2021-11-18 11:20:06.598764 - ❌ No reference table for schema etalab/schema-sdirve
# 2021-11-18 11:20:06.598940 - ❌ No reference table for schema etalab/schema-stationnement
# 2021-11-18 11:20:06.599111 - ❌ No reference table for schema etalab/schema-stationnement-cyclable
# 2021-11-18 11:20:06.599146 - ❌ No reference table for schema etalab/schema-vehicules-faibles-emissions-renouvellement-parc
# 2021-11-18 11:20:06.599176 - ❌ No reference table for schema openmaraude/schema-stationstaxi
# 2021-11-18 11:20:06.599203 - ❌ No reference table for schema scdl/budget
# 2021-11-18 11:20:06.599340 - ❌ No reference table for schema scdl/catalogue
# 2021-11-18 11:20:06.599393 - ❌ No reference table for schema scdl/deliberations
# 2021-11-18 11:20:06.599563 - ❌ No reference table for schema scdl/equipements
# 2021-11-18 11:20:06.599750 - ❌ No reference table for schema scdl/menus-collectifs
# 2021-11-18 11:20:06.599930 - ❌ No reference table for schema scdl/plats-menus-collectifs
# 2021-11-18 11:20:06.599969 - ❌ No reference table for schema scdl/subventions
# CPU times: user 33.9 ms, sys: 8.72 ms, total: 42.6 ms
# Wall time: 40.2 ms

# %%
shutil.move(TMP_FOLDER + 'consolidated_data', OUTPUT_DATA_FOLDER)
shutil.move(TMP_FOLDER + 'ref_tables', OUTPUT_DATA_FOLDER)
shutil.move(TMP_FOLDER + 'report_tables', OUTPUT_DATA_FOLDER)
# Out:
# '/tmp/consolidation-schemas/20211118/output/report_tables'
